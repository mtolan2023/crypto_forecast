# %% [markdown]
# ## BTC Model deployment (30 day lookback)
#
# This notebook will import new data to feed into the trained LSTM model and produce csvs of close price and predictions.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import json
import datetime as dt
from copy import deepcopy as dc
from tensorflow.keras.models import Sequential
from keras.models import load_model

from api_keys import coinapi_key
# Out:
# 2023-09-18 17:31:15.053331: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Pull BTC data from coinapi

url = 'https://rest.coinapi.io/v1/ohlcv/BITSTAMP_SPOT_BTC_USD/history?period_id=1DAY&&time_start=2023-01-02T00:00:00&limit=10000'
headers = {'X-CoinAPI-Key' : coinapi_key}
response = requests.get(url, headers=headers)
 
if response.status_code == 200:
    json_data = response.json()
    print(json_data)
else:
    print(f"Error: {response.status_code}")
# Out:
# [{'time_period_start': '2023-01-02T00:00:00.0000000Z', 'time_period_end': '2023-01-03T00:00:00.0000000Z', 'time_open': '2023-01-02T00:00:23.5020000Z', 'time_close': '2023-01-02T23:59:47.2190000Z', 'price_open': 16615, 'price_high': 16782, 'price_low': 16552, 'price_close': 16673, 'volume_traded': 1046.6584368, 'trades_count': 9780}, {'time_period_start': '2023-01-03T00:00:00.0000000Z', 'time_period_end': '2023-01-04T00:00:00.0000000Z', 'time_open': '2023-01-03T00:00:27.4330000Z', 'time_close': '2023-01-03T23:59:51.6650000Z', 'price_open': 16668, 'price_high': 16766, 'price_low': 16605, 'price_close': 16670, 'volume_traded': 1388.07196613, 'trades_count': 11861}, {'time_period_start': '2023-01-04T00:00:00.0000000Z', 'time_period_end': '2023-01-05T00:00:00.0000000Z', 'time_open': '2023-01-04T00:00:39.2340000Z', 'time_close': '2023-01-04T23:59:41.4680000Z', 'price_open': 16673, 'price_high': 16984, 'price_low': 16652, 'price_close': 16849, 'volume_traded': 2038.03012252, 'trades_count': 15672}, {'time_period_start': '2023-01-05T00:00:00.0000000Z', 'time_period_end': '2023-01-06T00:00:00.0000000Z', 'time_open': '2023-01-05T00:00:05.6030000Z', 'time_close': '2023-01-05T23:59:29.2900000Z', 'price_open': 16847, 'price_high': 16871, 'price_low': 16755, 'price_close': 16826, 'volume_traded': 1129.00352895, 'trades_count': 10216}, {'time_period_start': '2023-01-06T00:00:00.0000000Z', 'time_period_end': '2023-01-07T00:00:00.0000000Z', 'time_open': '2023-01-06T00:00:22.2310000Z', 'time_close': '2023-01-06T23:59:32.5910000Z', 'price_open': 16826, 'price_high': 17024, 'price_low': 16669, 'price_close': 16950, 'volume_traded': 1728.75684038, 'trades_count': 12381}, {'time_period_start': '2023-01-07T00:00:00.0000000Z', 'time_period_end': '2023-01-08T00:00:00.0000000Z', 'time_open': '2023-01-07T00:00:06.7510000Z', 'time_close': '2023-01-07T23:59:59.4220000Z', 'price_open': 16951, 'price_high': 16975, 'price_low': 16907, 'price_close': 16945, 'volume_traded': 526.82727294, 'trades_count': 6702}, {'time_period_start': '2023-01-08T00:00:00.0000000Z', 'time_period_end': '2023-01-09T00:00:00.0000000Z', 'time_open': '2023-01-08T00:00:19.9610000Z', 'time_close': '2023-01-08T23:59:46.3930000Z', 'price_open': 16946, 'price_high': 17163, 'price_low': 16915, 'price_close': 17119, 'volume_traded': 811.52324917, 'trades_count': 7131}, {'time_period_start': '2023-01-09T00:00:00.0000000Z', 'time_period_end': '2023-01-10T00:00:00.0000000Z', 'time_open': '2023-01-09T00:00:05.5860000Z', 'time_close': '2023-01-09T23:59:53.7640000Z', 'price_open': 17124, 'price_high': 17393, 'price_low': 17108, 'price_close': 17179, 'volume_traded': 2213.34824624, 'trades_count': 12463}, {'time_period_start': '2023-01-10T00:00:00.0000000Z', 'time_period_end': '2023-01-11T00:00:00.0000000Z', 'time_open': '2023-01-10T00:00:07.9780000Z', 'time_close': '2023-01-10T23:59:32.2260000Z', 'price_open': 17177, 'price_high': 17490, 'price_low': 17147, 'price_close': 17446, 'volume_traded': 1354.43514717, 'trades_count': 10155}, {'time_period_start': '2023-01-11T00:00:00.0000000Z', 'time_period_end': '2023-01-12T00:00:00.0000000Z', 'time_open': '2023-01-11T00:00:06.7860000Z', 'time_close': '2023-01-11T23:59:28.6950000Z', 'price_open': 17448, 'price_high': 17992, 'price_low': 17318, 'price_close': 17930, 'volume_traded': 1904.45231601, 'trades_count': 12211}, {'time_period_start': '2023-01-12T00:00:00.0000000Z', 'time_period_end': '2023-01-13T00:00:00.0000000Z', 'time_open': '2023-01-12T00:00:02.7450000Z', 'time_close': '2023-01-12T23:59:40.3920000Z', 'price_open': 17948, 'price_high': 19114, 'price_low': 17911, 'price_close': 18853, 'volume_traded': 5124.47523039, 'trades_count': 24707}, {'time_period_start': '2023-01-13T00:00:00.0000000Z', 'time_period_end': '2023-01-14T00:00:00.0000000Z', 'time_open': '2023-01-13T00:00:03.3830000Z', 'time_close': '2023-01-13T23:59:33.0100000Z', 'price_open': 18852, 'price_high': 19991, 'price_low': 18720, 'price_close': 19931, 'volume_traded': 3729.5302288 ...

# %%
#Convert json to pandas df
df = pd.DataFrame(json_data)

df.head()
# Out:
#               time_period_start               time_period_end  \
# 0  2023-01-02T00:00:00.0000000Z  2023-01-03T00:00:00.0000000Z
# 1  2023-01-03T00:00:00.0000000Z  2023-01-04T00:00:00.0000000Z
# 2  2023-01-04T00:00:00.0000000Z  2023-01-05T00:00:00.0000000Z
# 3  2023-01-05T00:00:00.0000000Z  2023-01-06T00:00:00.0000000Z
# 4  2023-01-06T00:00:00.0000000Z  2023-01-07T00:00:00.0000000Z
#
#                       time_open                    time_close  price_open  \
# 0  2023-01-02T00:00:23.5020000Z  2023-01-02T23:59:47.2190000Z       16615
# 1  2023-01-03T00:00:27.4330000Z  2023-01-03T23:59:51.6650000Z       16668
# 2  2023-01-04T00:00:39.2340000Z  2023-01-04T23:59:41.4680000Z       16673
# 3  2023-01-05T00:00:05.6030000Z  2023-01-05T23:59:29.2900000Z       16847
# 4  2023-01-06T00:00:22.2310000Z  2023-01-06T23:59:32.5910000Z       16826
#
#    price_high  price_low  price_close  volume_traded  trades_count
# 0       16782      16552        16673    1046.658437          9780
# 1       16766      16605        16670    1388.071966         11861
# 2       16984      16652        16849    2038.030123         15672
# 3       16871      16755        16826    1129.003529         10216
# 4       17024      16669        16950    1728.756840         12381

# %%
#reduce df to x and y columns
data = df[["time_period_start", "price_close"]]

#rename columns
data = data.rename(columns={"time_period_start":"Date","price_close":"Close"})

#convert date to dt, refomat to yyyymmdd
data['Date'] = pd.to_datetime(data['Date']).dt.date

#set date as index
data.set_index('Date', inplace=True)

data
# Out:
#             Close
# Date
# 2023-01-02  16673
# 2023-01-03  16670
# 2023-01-04  16849
# 2023-01-05  16826
# 2023-01-06  16950
# ...           ...
# 2023-09-14  26529
# 2023-09-15  26607
# 2023-09-16  26571
# 2023-09-17  26535
# 2023-09-18  26811
#
# [256 rows x 1 columns]

# %%
close = data['Close']

# %%
#plot historical eth price
plt.plot(close)

# %%
# build 29 day lookback for lstm prediction (we aren't splitting off a y)
def prepare_dataframe_for_lstm(data, n_steps):
    data = dc(data)
    
    for i in range(1, n_steps+1):
        data[f'Close(t-{i})'] = data['Close'].shift(i)
        
    data.dropna(inplace=True)
    
    return data

lookback = 29
shifted_df = prepare_dataframe_for_lstm(data, lookback)
shifted_df
# Out:
#             Close  Close(t-1)  Close(t-2)  Close(t-3)  Close(t-4)  Close(t-5)  \
# Date
# 2023-01-31  23127     22831.0     23746.0     23033.0     23083.0     23010.0
# 2023-02-01  23735     23127.0     22831.0     23746.0     23033.0     23083.0
# 2023-02-02  23498     23735.0     23127.0     22831.0     23746.0     23033.0
# 2023-02-03  23434     23498.0     23735.0     23127.0     22831.0     23746.0
# 2023-02-04  23330     23434.0     23498.0     23735.0     23127.0     22831.0
# ...           ...         ...         ...         ...         ...         ...
# 2023-09-14  26529     26226.0     25844.0     25155.0     25836.0     25899.0
# 2023-09-15  26607     26529.0     26226.0     25844.0     25155.0     25836.0
# 2023-09-16  26571     26607.0     26529.0     26226.0     25844.0     25155.0
# 2023-09-17  26535     26571.0     26607.0     26529.0     26226.0     25844.0
# 2023-09-18  26811     26535.0     26571.0     26607.0     26529.0     26226.0
#
#             Close(t-6)  Close(t-7)  Close(t-8)  Close(t-9)  ...  Close(t-20)  \
# Date                                                        ...
# 2023-01-31     23054.0     22637.0     22922.0     22717.0  ...      17930.0
# 2023-02-01     23010.0     23054.0     22637.0     22922.0  ...      18853.0
# 2023-02-02     23083.0     23010.0     23054.0     22637.0  ...      19931.0
# 2023-02-03     23033.0     23083.0     23010.0     23054.0  ...      20960.0
# 2023-02-04     23746.0     23033.0     23083.0     23010.0  ...      20885.0
# ...                ...         ...         ...         ...  ...          ...
# 2023-09-14     25908.0     26245.0     25748.0     25783.0  ...      26048.0
# 2023-09-15     25899.0     25908.0     26245.0     25748.0  ...      26008.0
# 2023-09-16     25836.0     25899.0     25908.0     26245.0  ...      26090.0
# 2023-09-17     25155.0     25836.0     25899.0     25908.0  ...      26103.0
# 2023-09-18     25844.0     25155.0     25836.0     25899.0  ...      27726.0
#
#             Close(t-21)  Close(t-22)  Close(t-23)  Close(t-24)  Close(t-25)  \
# Date
# 2023-01-31      17446.0      17179.0      17119.0      16945.0      16950.0
# 2023-02-01      17930.0      17446.0      17179.0      17119.0      16945.0
# 2023-02-02      18853.0      17930.0      17446.0      17179.0      17119.0
# 2023-02-03      19931.0      18853.0      17930.0      17446.0      17179.0
# 2023-02-04      20960.0      19931.0      18853.0      17930.0      17446.0
# ...                 ...          ...          ...          ...          ...
# 2023-09-14      26168.0      26431.0      26042.0      26125.0      26192.0
# 2023-09-15      26048.0      26168.0      26431.0      26042.0      26125.0
# 2023-09-16      26008.0      26048.0      26168.0      26431.0      26042.0
# 2023-09-17      26090.0      26008.0      26048.0      26168.0      26431.0
# 2023-09-18      26103.0      26090.0      26008.0      26048.0      26168.0
#
#             Close(t-26)  Close(t-27)  Close(t-28)  Close(t-29)
# Date
# 2023-01-31      16826.0      16849.0      16670.0      16673.0
# 2023-02-01      16950.0      16826.0      16849.0      16670.0
# 2023-02-02      16945.0      16950.0      16826.0      16849.0
# 2023-02-03      17119.0      16945.0      16950.0      16826.0
# 2023-02-04      17179.0      17119.0      16945.0      16950.0
# ...                 ...          ...          ...          ...
# 2023-09-14      26097.0      26051.0      26642.0      28701.0
# 2023-09-15      26192.0      26097.0      26051.0      26642.0
# 2023-09-16      26125.0      26192.0      26097.0      26051.0
# 2023-09-17      26042.0      26125.0      26192.0      26097.0
# 2023-09-18      26431.0      26042.0      26125.0      26192.0
#
# [227 rows x 30 columns]

# %%
#create array of dates for plotting from new index. 
dates = shifted_df.index

dates.shape
# Out:
# (227,)

# %%
#convert from df to numpy array
shifted_df_as_np = shifted_df.to_numpy()

shifted_df_as_np

#Log scale data
log_transformed_data = np.log(shifted_df_as_np)

log_transformed_data.shape
# Out:
# (227, 30)

# %%
#Flip lookback axis so that most recent day is last -7, -6, -5, -4, -3, -2, -1, predict next
X = dc(np.flip(log_transformed_data, axis=1))

# %%
#load trained model
model = load_model("H5_Files/btc_30_day_1.h5")

# %%
#build predictions for first model
predictions = []
predicted_dates = []
prediction_range = 7

#create list of numbers to add to date based on date range
date_range = list(range(1, prediction_range +1))


# Use last (most recent) window to predict next day
current_batch = X[-1]
current_reshape = current_batch.reshape((1, 30, 1))
initial_date = dates[-1]

for i in range(prediction_range):  # Generate predictions for 7 days
    # Predict the next data point
    current_pred = model.predict(current_reshape)[0,0]
    
    # Append the prediction to the list of predictions
    predictions.append(current_pred)
        
    # Update initial input for the next step
    updated_batch = np.insert(current_batch, -1, current_pred)
    
    #resize batch 
    current_batch = updated_batch[1:]
    
    #reshape batch
    current_reshape = current_batch.reshape((1, 30, 1))

    
#Add future dates for predictions  
for day in date_range:
    new_date = initial_date + dt.timedelta(days=day)
    predicted_dates.append(new_date
                          )
# 'predictions' contains 7-day forecast
print(predictions)

for date in predicted_dates:
    print(date)
# Out:
# 1/1 [==============================] - 0s 418ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# [10.256489, 10.260475, 10.2605505, 10.261296, 10.261892, 10.262212, 10.262355]
# 2023-09-19
# 2023-09-20
# 2023-09-21
# 2023-09-22
# 2023-09-23
# 2023-09-24
# 2023-09-25

# %%
#load trained model 2
model2 = load_model("H5_Files/btc_30_day_2.h5")
#load trained model 3
model3 = load_model("H5_Files/btc_30_day_3.h5")

# %%
#build predictions for second 2 models

# Initialize an array to store predictions
predictions2 = []
prediction_range2 = 7

current_batch = X[-1]
current_reshape = current_batch.reshape((1, 30, 1))
initial_date = dates[-1]

for i in range(prediction_range):  # Generate predictions for 7 days
    # Predict the next data point
    current_pred = model2.predict(current_reshape)[0,0]
    
    # Append the prediction to the list of predictions
    predictions2.append(current_pred)
        
    # Update initial input for the next step
    updated_batch = np.insert(current_batch, -1, current_pred)
    
    #resize batch 
    current_batch = updated_batch[1:]
    
    #reshape batch
    current_reshape = current_batch.reshape((1, 30, 1))

    #build predictions for first model


    # Initialize an array to store predictions
predictions3 = []
prediction_range3 = 7

current_batch = X[-1]
current_reshape = current_batch.reshape((1, 30, 1))
initial_date = dates[-1]

for i in range(prediction_range):  # Generate predictions for 7 days
    # Predict the next data point
    current_pred = model3.predict(current_reshape)[0,0]
    
    # Append the prediction to the list of predictions
    predictions3.append(current_pred)
        
    # Update initial input for the next step
    updated_batch = np.insert(current_batch, -1, current_pred)
    
    #resize batch 
    current_batch = updated_batch[1:]
    
    #reshape batch
    current_reshape = current_batch.reshape((1, 30, 1))

print(predictions2)
print(predictions3)
# Out:
# 1/1 [==============================] - 0s 449ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 443ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# [10.214636, 10.217476, 10.21821, 10.218645, 10.218896, 10.219032, 10.219122]
# [10.204927, 10.20729, 10.207151, 10.206882, 10.206704, 10.206566, 10.206456]

# %%
plt.plot(close)
plt.plot(predicted_dates, np.exp(predictions))
plt.xticks(rotation=90)

plt.show()

# %%
# build output into a df for graphing in js

df = pd.DataFrame({"Date": dates, "observed":close[lookback:]})
df.set_index('Date', inplace=True)

df2 = pd.DataFrame({"Date": predicted_dates, "future_prediction":np.exp(predictions),\
                    "future_prediction2": np.exp(predictions2), "future_prediction3": np.exp(predictions3)})
df2.set_index('Date', inplace=True)                   
                    
past_future_df = pd.merge(df,df2, how='outer', left_index=True, right_index=True)


past_future_df.head()
# Out:
#             observed  future_prediction  future_prediction2  \
# Date
# 2023-01-31   23127.0                NaN                 NaN
# 2023-02-01   23735.0                NaN                 NaN
# 2023-02-02   23498.0                NaN                 NaN
# 2023-02-03   23434.0                NaN                 NaN
# 2023-02-04   23330.0                NaN                 NaN
#
#             future_prediction3
# Date
# 2023-01-31                 NaN
# 2023-02-01                 NaN
# 2023-02-02                 NaN
# 2023-02-03                 NaN
# 2023-02-04                 NaN

# %%
past_future_df.tail(12)
# Out:
#             observed  future_prediction  future_prediction2  \
# Date
# 2023-09-14   26529.0                NaN                 NaN
# 2023-09-15   26607.0                NaN                 NaN
# 2023-09-16   26571.0                NaN                 NaN
# 2023-09-17   26535.0                NaN                 NaN
# 2023-09-18   26811.0                NaN                 NaN
# 2023-09-19       NaN       28466.660156        27299.833984
# 2023-09-20       NaN       28580.361328        27377.474609
# 2023-09-21       NaN       28582.517578        27397.585938
# 2023-09-22       NaN       28603.839844        27409.503906
# 2023-09-23       NaN       28620.894531        27416.378906
# 2023-09-24       NaN       28630.041016        27420.121094
# 2023-09-25       NaN       28634.134766        27422.578125
#
#             future_prediction3
# Date
# 2023-09-14                 NaN
# 2023-09-15                 NaN
# 2023-09-16                 NaN
# 2023-09-17                 NaN
# 2023-09-18                 NaN
# 2023-09-19        27036.078125
# 2023-09-20        27100.017578
# 2023-09-21        27096.271484
# 2023-09-22        27088.986328
# 2023-09-23        27084.154297
# 2023-09-24        27080.408203
# 2023-09-25        27077.441406

# %%
pred_columns = past_future_df[['future_prediction','future_prediction2','future_prediction3' ]]

pred_means = pred_columns.mean(axis=1)

past_future_df['mean'] = pred_means

past_future_df_30 = past_future_df.copy()

past_future_df_30
# Out:
#             observed  future_prediction  future_prediction2  \
# Date
# 2023-01-31   23127.0                NaN                 NaN
# 2023-02-01   23735.0                NaN                 NaN
# 2023-02-02   23498.0                NaN                 NaN
# 2023-02-03   23434.0                NaN                 NaN
# 2023-02-04   23330.0                NaN                 NaN
# ...              ...                ...                 ...
# 2023-09-21       NaN       28582.517578        27397.585938
# 2023-09-22       NaN       28603.839844        27409.503906
# 2023-09-23       NaN       28620.894531        27416.378906
# 2023-09-24       NaN       28630.041016        27420.121094
# 2023-09-25       NaN       28634.134766        27422.578125
#
#             future_prediction3          mean
# Date
# 2023-01-31                 NaN           NaN
# 2023-02-01                 NaN           NaN
# 2023-02-02                 NaN           NaN
# 2023-02-03                 NaN           NaN
# 2023-02-04                 NaN           NaN
# ...                        ...           ...
# 2023-09-21        27096.271484  27692.125000
# 2023-09-22        27088.986328  27700.775391
# 2023-09-23        27084.154297  27707.142578
# 2023-09-24        27080.408203  27710.189453
# 2023-09-25        27077.441406  27711.384766
#
# [234 rows x 5 columns]

# %%
past_future_df_30.to_csv('output/btc_model_30.csv')
