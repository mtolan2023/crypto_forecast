# %% [markdown]
# ## Crypto Prediction with LSTM: Ethereum (ETH)
#
# ## 30 Day lookback
#
# - This notebook attempts to use TensorFlow Keras LSTM to predict movement in Crypto prices
# - Data is pulled from the CoinApi, so it can be refreshed at any point and retrained
# - 2 optimizations were used and an overall R2 score of .86 was attained
# - This update uses a 30 day lookback window, in order to assess whether the greater lookback time has an impact on training and prediction.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import json
import tensorflow as tf
from copy import deepcopy as dc
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.layers import *
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from tensorflow.keras.optimizers import Adam
import datetime as dt

import nasdaqdatalink

from api_keys import coinapi_key
# Out:
# 2023-09-18 18:21:09.286851: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
#  https://docs.coinapi.io/market-data/rest-api/ohlcv
# Pull ETH data from coinapi

url = 'https://rest.coinapi.io/v1/ohlcv/BITSTAMP_SPOT_ETH_USD/history?period_id=1DAY&limit=20000'
headers = {'X-CoinAPI-Key' : coinapi_key}
response = requests.get(url, headers=headers)
 
if response.status_code == 200:
    json_data = response.json()
    print(json_data)
else:
    print(f"Error: {response.status_code}")
# Out:
# [{'time_period_start': '2023-09-18T00:00:00.0000000Z', 'time_period_end': '2023-09-19T00:00:00.0000000Z', 'time_open': '2023-09-18T00:00:07.0460000Z', 'time_close': '2023-09-18T22:20:57.6320000Z', 'price_open': 1623.3, 'price_high': 1669.2, 'price_low': 1606, 'price_close': 1640.6, 'volume_traded': 3843.61805174, 'trades_count': 5363}, {'time_period_start': '2023-09-17T00:00:00.0000000Z', 'time_period_end': '2023-09-18T00:00:00.0000000Z', 'time_open': '2023-09-17T00:00:22.7270000Z', 'time_close': '2023-09-17T23:59:45.8490000Z', 'price_open': 1634.9, 'price_high': 1635.6, 'price_low': 1613, 'price_close': 1623.3, 'volume_traded': 1544.80676936, 'trades_count': 3412}, {'time_period_start': '2023-09-16T00:00:00.0000000Z', 'time_period_end': '2023-09-17T00:00:00.0000000Z', 'time_open': '2023-09-16T00:00:18.8370000Z', 'time_close': '2023-09-16T23:59:46.7840000Z', 'price_open': 1642.4, 'price_high': 1652.3, 'price_low': 1632.1, 'price_close': 1635, 'volume_traded': 1343.66683579, 'trades_count': 3983}, {'time_period_start': '2023-09-15T00:00:00.0000000Z', 'time_period_end': '2023-09-16T00:00:00.0000000Z', 'time_open': '2023-09-15T00:00:00.4470000Z', 'time_close': '2023-09-15T23:59:48.2460000Z', 'price_open': 1627.1, 'price_high': 1653.1, 'price_low': 1612, 'price_close': 1641.5, 'volume_traded': 3623.07439861, 'trades_count': 5783}, {'time_period_start': '2023-09-14T00:00:00.0000000Z', 'time_period_end': '2023-09-15T00:00:00.0000000Z', 'time_open': '2023-09-14T00:00:04.4670000Z', 'time_close': '2023-09-14T23:59:58.0310000Z', 'price_open': 1608.1, 'price_high': 1644.4, 'price_low': 1607.5, 'price_close': 1627.1, 'volume_traded': 5650.19914773, 'trades_count': 5572}, {'time_period_start': '2023-09-13T00:00:00.0000000Z', 'time_period_end': '2023-09-14T00:00:00.0000000Z', 'time_open': '2023-09-13T00:00:26.8010000Z', 'time_close': '2023-09-13T23:58:55.8280000Z', 'price_open': 1593.2, 'price_high': 1618.2, 'price_low': 1581.8, 'price_close': 1608.1, 'volume_traded': 4672.30203902, 'trades_count': 4862}, {'time_period_start': '2023-09-12T00:00:00.0000000Z', 'time_period_end': '2023-09-13T00:00:00.0000000Z', 'time_open': '2023-09-12T00:00:07.1670000Z', 'time_close': '2023-09-12T23:59:55.8680000Z', 'price_open': 1551.5, 'price_high': 1622.3, 'price_low': 1549.3, 'price_close': 1593.3, 'volume_traded': 5455.60411831, 'trades_count': 5349}, {'time_period_start': '2023-09-11T00:00:00.0000000Z', 'time_period_end': '2023-09-12T00:00:00.0000000Z', 'time_open': '2023-09-11T00:00:04.8170000Z', 'time_close': '2023-09-11T23:59:44.3110000Z', 'price_open': 1616.8, 'price_high': 1618.6, 'price_low': 1531.1, 'price_close': 1551.7, 'volume_traded': 17012.27092943, 'trades_count': 7622}, {'time_period_start': '2023-09-10T00:00:00.0000000Z', 'time_period_end': '2023-09-11T00:00:00.0000000Z', 'time_open': '2023-09-10T00:00:12.4050000Z', 'time_close': '2023-09-10T23:59:39.1390000Z', 'price_open': 1635.6, 'price_high': 1635.6, 'price_low': 1596.7, 'price_close': 1616.8, 'volume_traded': 3106.31110721, 'trades_count': 4149}, {'time_period_start': '2023-09-09T00:00:00.0000000Z', 'time_period_end': '2023-09-10T00:00:00.0000000Z', 'time_open': '2023-09-09T00:00:01.0110000Z', 'time_close': '2023-09-09T23:58:29.6580000Z', 'price_open': 1636, 'price_high': 1637.3, 'price_low': 1629.7, 'price_close': 1635.3, 'volume_traded': 1588.74111545, 'trades_count': 5245}, {'time_period_start': '2023-09-08T00:00:00.0000000Z', 'time_period_end': '2023-09-09T00:00:00.0000000Z', 'time_open': '2023-09-08T00:00:05.8280000Z', 'time_close': '2023-09-08T23:59:25.6100000Z', 'price_open': 1647.8, 'price_high': 1658.1, 'price_low': 1616.1, 'price_close': 1636, 'volume_traded': 3926.05948046, 'trades_count': 10596}, {'time_period_start': '2023-09-07T00:00:00.0000000Z', 'time_period_end': '2023-09-08T00:00:00.0000000Z', 'time_open': '2023-09-07T00:00:05.9800000Z', 'time_close': '2023-09-07T23:59:45.6740000Z', 'price_open': 1632.2, 'price_high': 1658.1, 'price_low': 1622.6, 'price_close': 1647 ...

# %%
#Convert json to pandas df
df = pd.DataFrame(json_data)

df.head()
# Out:
#               time_period_start               time_period_end  \
# 0  2023-09-18T00:00:00.0000000Z  2023-09-19T00:00:00.0000000Z
# 1  2023-09-17T00:00:00.0000000Z  2023-09-18T00:00:00.0000000Z
# 2  2023-09-16T00:00:00.0000000Z  2023-09-17T00:00:00.0000000Z
# 3  2023-09-15T00:00:00.0000000Z  2023-09-16T00:00:00.0000000Z
# 4  2023-09-14T00:00:00.0000000Z  2023-09-15T00:00:00.0000000Z
#
#                       time_open                    time_close  price_open  \
# 0  2023-09-18T00:00:07.0460000Z  2023-09-18T22:20:57.6320000Z      1623.3
# 1  2023-09-17T00:00:22.7270000Z  2023-09-17T23:59:45.8490000Z      1634.9
# 2  2023-09-16T00:00:18.8370000Z  2023-09-16T23:59:46.7840000Z      1642.4
# 3  2023-09-15T00:00:00.4470000Z  2023-09-15T23:59:48.2460000Z      1627.1
# 4  2023-09-14T00:00:04.4670000Z  2023-09-14T23:59:58.0310000Z      1608.1
#
#    price_high  price_low  price_close  volume_traded  trades_count
# 0      1669.2     1606.0       1640.6    3843.618052          5363
# 1      1635.6     1613.0       1623.3    1544.806769          3412
# 2      1652.3     1632.1       1635.0    1343.666836          3983
# 3      1653.1     1612.0       1641.5    3623.074399          5783
# 4      1644.4     1607.5       1627.1    5650.199148          5572

# %%
#reduce df to x and y columns
data = df[["time_period_start", "price_close"]]

#rename columns
data = data.rename(columns={"time_period_start":"Date","price_close":"Close"})

#convert date to dt, refomat to yyyymmdd
data['Date'] = pd.to_datetime(data['Date']).dt.date

#json return began with most recent date, reversed for plotting/analysis
data = data.reindex(index=data.index[::-1])

#set date as index
data.set_index('Date', inplace=True)

data.head()
# Out:
#              Close
# Date
# 2017-08-20  298.40
# 2017-08-21  319.31
# 2017-08-22  312.22
# 2017-08-23  315.61
# 2017-08-24  323.84

# %%
#plot historical eth price
plt.plot(data)

# %%
# Set parameters for model

lookback = 30

split_1 = .8
split_2 = .9

# %%
# build lookback for lstm training
def prepare_dataframe_for_lstm(data, n_steps):
    data = dc(data)
    
    for i in range(1, n_steps+1):
        data[f'Close(t-{i})'] = data['Close'].shift(i)
        
    data.dropna(inplace=True)
    
    return data

shifted_df = prepare_dataframe_for_lstm(data, lookback)

# name date column from new index (since start date is absorbed into first x windows)
dates = shifted_df.index

#convert from df to numpy array
shifted_df_as_np = shifted_df.to_numpy()

# scale to log
log_transformed_data = np.log(shifted_df_as_np)



# split y from features
X1 = log_transformed_data[:, 1:]
y1 = log_transformed_data[:, 0]

#flip order of windows (needs to start with most recent)

X1 = dc(np.flip(X1, axis=1))
X1


X1.shape, y1.shape, dates.shape
# Out:
# ((2181, 30), (2181,), (2181,))

# %%
#Calculate split points based on previously defined variables
train_split = int(len(X1) * split_1)
test_split = int(len(X1) * split_2)

#Define spilt points for train/val/test
dates_train1, X_train1, y_train1 = dates[:train_split],X1[:train_split], y1[:train_split]
dates_val1, X_val1, y_val1 = dates[train_split:test_split], X1[train_split:test_split], y1[train_split:test_split]
dates_test1, X_test1, y_test1 = dates[test_split:], X1[test_split:], y1[test_split:]
X_train1.shape, y_train1.shape, X_val1.shape, y_val1.shape, X_test1.shape, y_test1.shape
# Out:
# ((1744, 30), (1744,), (218, 30), (218,), (219, 30), (219,))

# %%
#Build, compile, fit LSTM model

model = Sequential([layers.Input((lookback, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), epochs=100)
# Out:
# 2023-09-18 18:21:28.332859: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/100
# 55/55 [==============================] - 5s 35ms/step - loss: 31.4309 - mean_absolute_error: 5.3835 - val_loss: 12.5129 - val_mean_absolute_error: 3.5344
# Epoch 2/100
# 55/55 [==============================] - 1s 20ms/step - loss: 1.9615 - mean_absolute_error: 1.1603 - val_loss: 0.7238 - val_mean_absolute_error: 0.8391
# Epoch 3/100
# 55/55 [==============================] - 1s 22ms/step - loss: 0.8221 - mean_absolute_error: 0.7652 - val_loss: 0.0474 - val_mean_absolute_error: 0.1773
# Epoch 4/100
# 55/55 [==============================] - 1s 19ms/step - loss: 0.1486 - mean_absolute_error: 0.2982 - val_loss: 0.2148 - val_mean_absolute_error: 0.4073
# Epoch 5/100
# 55/55 [==============================] - 1s 19ms/step - loss: 0.0608 - mean_absolute_error: 0.1960 - val_loss: 0.1223 - val_mean_absolute_error: 0.2992
# Epoch 6/100
# 55/55 [==============================] - 1s 19ms/step - loss: 0.0338 - mean_absolute_error: 0.1445 - val_loss: 0.0228 - val_mean_absolute_error: 0.1239
# Epoch 7/100
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0255 - mean_absolute_error: 0.1196 - val_loss: 0.0346 - val_mean_absolute_error: 0.1622
# Epoch 8/100
# 55/55 [==============================] - 1s 19ms/step - loss: 0.0166 - mean_absolute_error: 0.0984 - val_loss: 0.0328 - val_mean_absolute_error: 0.1637
# Epoch 9/100
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0141 - mean_absolute_error: 0.0915 - val_loss: 0.0161 - val_mean_absolute_error: 0.1095
# Epoch 10/100
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0121 - mean_absolute_error: 0.0862 - val_loss: 0.0054 - val_mean_absolute_error: 0.0534
# Epoch 11/100
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0105 - mean_absolute_error: 0.0781 - val_loss: 0.0057 - val_mean_absolute_error: 0.0546
# Epoch 12/100
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0092 - mean_absolute_error: 0.0720 - val_loss: 0.0060 - val_mean_absolute_error: 0.0608
# Epoch 13/100
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0099 - mean_absolute_error: 0.0761 - val_loss: 0.0041 - val_mean_absolute_error: 0.0452
# Epoch 14/100
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0081 - mean_absolute_error: 0.0676 - val_loss: 0.0067 - val_mean_absolute_error: 0.0682
# Epoch 15/100
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0093 - mean_absolute_error: 0.0746 - val_loss: 0.0135 - val_mean_absolute_error: 0.1008
# Epoch 16/100
# 55/55 [==============================] - 1s 19ms/step - loss: 0.0075 - mean_absolute_error: 0.0651 - val_loss: 0.0039 - val_mean_absolute_error: 0.0432
# Epoch 17/100
# 55/55 [==============================] - 1s 19ms/step - loss: 0.0071 - mean_absolute_error: 0.0629 - val_loss: 0.0038 - val_mean_absolute_error: 0.0429
# Epoch 18/100
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0067 - mean_absolute_error: 0.0611 - val_loss: 0.0067 - val_mean_absolute_error: 0.0687
# Epoch 19/100
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0070 - mean_absolute_error: 0.0637 - val_loss: 0.0140 - val_mean_absolute_error: 0.1040
# Epoch 20/100
# 55/55 [==============================] - 1s 24ms/step - loss: 0.0071 - mean_absolute_error: 0.0638 - val_loss: 0.0086 - val_mean_absolute_error: 0.0759
# Epoch 21/100
# 55/55 [==============================] - 1s 20ms/step - loss: 0.0063 - mean_absolute_error: 0.0602 - val_loss: 0.0034 - val_mean_absolute_error: 0.0420
# Epoch 22/100
# 55/55 [==============================] - 1s 20ms/step - loss: 0.0055 - mean_absolute_error: 0.0552 - val_loss: 0.0034 - val_mean_absolute_error: 0.0416
# Epoch 23/100
# 55/55 [==============================] - 1s 22ms/step - loss: 0.0070 - mean_absolute_error: 0.0640 - val_loss: 0.0043 - val_mean_absolute_error: 0.0470
# Epoch 24/100
# 55/55 [==============================] - 1s 19ms/step - loss: 0.0066 - mean_absolute_error: 0.0616 - val_loss: 0.0074 - val_mean_absolute_error: 0.0703
# Epoch 25/100
# 55/55 [==============================] - 1s 20ms/step - loss: 0.0060 - mean_absolute_error: 0.0588 - val_loss: 0.0041 - val_mean_absolute_error: 0.0499
# Epoch 26/100
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0055 - mean_absolute_error: 0.0555 - val_loss: 0.0030 - val_mean_absolute_error: 0.0385
# Epoch 27/100
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0061 - mean_absolute_error: 0.0587 - val_loss: 0.0043 - val_mean_absolute_error: 0.0481
# Epoch 28/100
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0055 - mean_absolute_error: 0.0551 - val_loss: 0.0031 - val_mean_absolute_error: 0.0379
# Epoch 29/100
# 55/55 [==============================] - 1s 19ms/step - loss: 0.0055 - mean_absolute_error: 0.0548 - val_loss: 0.0033 - val_mean_absolute_error: 0.0421
# Epoch 30/100
# 55/55 [==============================] - 1s 21ms/step - loss: 0.0064 - mean_absolute_error: 0.0614 - val_loss: 0.0029 - val_mean_absolute_error: 0.0370
# Epoch 31/100
# 55/55 [==============================] - 1s 20ms/step - loss: 0.0049 - mean_absolute_error: 0.0510 - val_loss: 0.0031 - val_mean_absolute_error: 0.0380
# Epoch 32/100
# 55/55 [==============================] - 1s 20ms/step - loss: 0.0069 - mean_absolute_error: 0.0643 - val_loss: 0.0080 - val_mean_absolute_error: 0.0794
# Epoch 33/100
# 55/55 [==============================] - 1s 20ms/step - loss: 0.0057 - mean_absolute_error: 0.0577 - val_loss: 0.0070 - val_mean_absolute_error: 0.0734
# Epoch 34/100
# 55/55 [==============================] - 1s 21ms/step - loss: 0.0057 - mean_absolute_error: 0.0576 - val_loss: 0.0031 - val_mean_absolute_error: 0.0389
# Epoch 35/100
# 55/55 [==============================] - 1s 19ms/step - loss: 0.0050 - mean_absolute_error: 0.0523 - val_loss: 0.0028 - val_mean_absolute_error: 0.0375
# Epoch 36/100
# 55/55 [==============================] - 1s 21ms/step - loss: 0.0047 - mean_absolute_error: 0.0507 - val_loss: 0.0047 - val_mean_absolute_error: 0.0569
# Epoch 37/100
# 55/55 [==============================] - 2s 28ms/step - loss: 0.0050 - mean_absolute_error: 0.0531 - val_loss: 0.0036 - val_mean_absolute_error: 0.0462
# Epoch 38/100
# 55/55 [==============================] - 1s 24ms/step - loss: 0.0050 - mean_absolute_error: 0.0532 - val_loss: 0.0027 - val_mean_absolute_error: 0.0367
# Epoch 39/100
# 55/55 [==============================] - 1s 19ms/step - loss: 0.0065 - mean_absolute_error: 0.0632 - val_loss: 0.0043 - val_mean_absolute_error: 0.0538
# Epoch 40/100
# 55/55 [==============================] - 1s 19ms/step - loss: 0.0057 - mean_absolute_error: 0.0576 - val_loss: 0.0121 - val_mean_absolute_error: 0.0988
# Epoch 41/100
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0049 - mean_absolute_error: 0.0528 - val_loss: 0.0027 - val_mean_absolute_error: 0.0372
# Epoch 42/100
# 55/55 [==============================] - 1s 19ms/step - loss: 0.0053 - mean_absolute_error: 0.0555 - val_loss: 0.0028 - val_mean_absolute_error: 0.0384
# Epoch 43/100
# 55/55 [==============================] - 1s 24ms/step - loss: 0.0046 - mean_absolute_error: 0.0509 - val_loss: 0.0031 - val_mean_absolute_error: 0.0414
# Epoch 44/100
# 55/55 [==============================] - 1s 19ms/step - loss: 0.0054 - mean_absolute_error: 0.0563 - val_loss: 0.0037 - val_mean_absolute_error: 0.0485
# Epoch 45/100
# 55/55 [==============================] - 1s 20ms/step - loss: 0.0052 - mean_absolute_error: 0.0548 - val_loss: 0.0025 - val_mean_absolute_error: 0.0350
# Epoch 46/100
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0053 - mean_absolute_error: 0.0564 - val_loss: 0.0052 - val_mean_absolute_error: 0.0583
# Epoch 47/100
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0047 - mean_absolute_error: 0.0516 - val_loss: 0.0028 - val_mean_absolute_error: 0.0374
# Epoch 48/100
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0040 - mean_absolute_error: 0.0458 - val_loss: 0.0025 - val_mean_absolute_error: 0.0341
# Epoch 49/100
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0046 - mean_absolute_error: 0.0507 - val_loss: 0.0035 - val_mean_absolute_error: 0.0465
# Epoch 50/100
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0040 - mean_absolute_error: 0.0467 - val_loss: 0.0033 - val_mean_absolute_error: 0.0448
# Epoch 51/100
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0043 - mean_absolute_error: 0.0496 - val_loss: 0.0027 - val_mean_absolute_error: 0.0366
# Epoch 52/100
# 55/55 [==============================] - 1s 19ms/step - loss: 0.0050 - mean_absolute_error: 0.0534 - val_loss: 0.0068 - val_mean_absolute_error: 0.0696
# Epoch 53/100
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0044 - mean_absolute_error: 0.0488 - val_loss: 0.0028 - val_mean_absolute_error: 0.0378
# Epoch 54/100
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0045 - mean_absolute_error: 0.0502 - val_loss: 0.0023 - val_mean_absolute_error: 0.0331
# Epoch 55/100
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0039 - mean_absolute_error: 0.0456 - val_loss: 0.0052 - val_mean_absolute_error: 0.0593
# Epoch 56/100
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0064 - mean_absolute_error: 0.0625 - val_loss: 0.0047 - val_mean_absolute_error: 0.0556
# Epoch 57/100
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0052 - mean_absolute_error: 0.0557 - val_loss: 0.0023 - val_mean_absolute_error: 0.0326
# Epoch 58/100
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0041 - mean_absolute_error: 0.0483 - val_loss: 0.0023 - val_mean_absolute_error: 0.0324
# Epoch 59/100
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0043 - mean_absolute_error: 0.0492 - val_loss: 0.0031 - val_mean_absolute_error: 0.0416
# Epoch 60/100
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0040 - mean_absolute_error: 0.0461 - val_loss: 0.0026 - val_mean_absolute_error: 0.0363
# Epoch 61/100
# 55/55 [==============================] - 1s 22ms/step - loss: 0.0051 - mean_absolute_error: 0.0559 - val_loss: 0.0120 - val_mean_absolute_error: 0.1021
# Epoch 62/100
# 55/55 [==============================] - 1s 26ms/step - loss: 0.0055 - mean_absolute_error: 0.0571 - val_loss: 0.0027 - val_mean_absolute_error: 0.0386
# Epoch 63/100
# 55/55 [==============================] - 2s 29ms/step - loss: 0.0064 - mean_absolute_error: 0.0621 - val_loss: 0.0025 - val_mean_absolute_error: 0.0364
# Epoch 64/100
# 55/55 [==============================] - 1s 27ms/step - loss: 0.0043 - mean_absolute_error: 0.0495 - val_loss: 0.0022 - val_mean_absolute_error: 0.0327
# Epoch 65/100
# 55/55 [==============================] - 1s 19ms/step - loss: 0.0041 - mean_absolute_error: 0.0476 - val_loss: 0.0063 - val_mean_absolute_error: 0.0707
# Epoch 66/100
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0047 - mean_absolute_error: 0.0513 - val_loss: 0.0047 - val_mean_absolute_error: 0.0564
# Epoch 67/100
# 55/55 [==============================] - 1s 20ms/step - loss: 0.0041 - mean_absolute_error: 0.0487 - val_loss: 0.0022 - val_mean_absolute_error: 0.0323
# Epoch 68/100
# 55/55 [==============================] - 1s 27ms/step - loss: 0.0048 - mean_absolute_error: 0.0539 - val_loss: 0.0059 - val_mean_absolute_error: 0.0657
# Epoch 69/100
# 55/55 [==============================] - 2s 37ms/step - loss: 0.0045 - mean_absolute_error: 0.0506 - val_loss: 0.0024 - val_mean_absolute_error: 0.0342
# Epoch 70/100
# 55/55 [==============================] - 1s 23ms/step - loss: 0.0042 - mean_absolute_error: 0.0484 - val_loss: 0.0090 - val_mean_absolute_error: 0.0844
# Epoch 71/100
# 55/55 [==============================] - 1s 21ms/step - loss: 0.0042 - mean_absolute_error: 0.0478 - val_loss: 0.0021 - val_mean_absolute_error: 0.0318
# Epoch 72/100
# 55/55 [==============================] - 1s 19ms/step - loss: 0.0037 - mean_absolute_error: 0.0448 - val_loss: 0.0021 - val_mean_absolute_error: 0.0307
# Epoch 73/100
# 55/55 [==============================] - 2s 33ms/step - loss: 0.0037 - mean_absolute_error: 0.0449 - val_loss: 0.0021 - val_mean_absolute_error: 0.0312
# Epoch 74/100
# 55/55 [==============================] - 1s 21ms/step - loss: 0.0041 - mean_absolute_error: 0.0484 - val_loss: 0.0071 - val_mean_absolute_error: 0.0733
# Epoch 75/100
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0042 - mean_absolute_error: 0.0489 - val_loss: 0.0030 - val_mean_absolute_error: 0.0431
# Epoch 76/100
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0040 - mean_absolute_error: 0.0470 - val_loss: 0.0052 - val_mean_absolute_error: 0.0609
# Epoch 77/100
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0042 - mean_absolute_error: 0.0493 - val_loss: 0.0029 - val_mean_absolute_error: 0.0415
# Epoch 78/100
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0035 - mean_absolute_error: 0.0434 - val_loss: 0.0025 - val_mean_absolute_error: 0.0377
# Epoch 79/100
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0041 - mean_absolute_error: 0.0471 - val_loss: 0.0024 - val_mean_absolute_error: 0.0361
# Epoch 80/100
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0043 - mean_absolute_error: 0.0489 - val_loss: 0.0029 - val_mean_absolute_error: 0.0414
# Epoch 81/100
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0047 - mean_absolute_error: 0.0523 - val_loss: 0.0026 - val_mean_absolute_error: 0.0383
# Epoch 82/100
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0037 - mean_absolute_error: 0.0453 - val_loss: 0.0023 - val_mean_absolute_error: 0.0346
# Epoch 83/100
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0046 - mean_absolute_error: 0.0512 - val_loss: 0.0029 - val_mean_absolute_error: 0.0423
# Epoch 84/100
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0039 - mean_absolute_error: 0.0452 - val_loss: 0.0021 - val_mean_absolute_error: 0.0310
# Epoch 85/100
# 55/55 [==============================] - 1s 15ms/step - loss: 0.0043 - mean_absolute_error: 0.0495 - val_loss: 0.0025 - val_mean_absolute_error: 0.0362
# Epoch 86/100
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0088 - mean_absolute_error: 0.0766 - val_loss: 0.0028 - val_mean_absolute_error: 0.0405
# Epoch 87/100
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0048 - mean_absolute_error: 0.0530 - val_loss: 0.0029 - val_mean_absolute_error: 0.0411
# Epoch 88/100
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0037 - mean_absolute_error: 0.0447 - val_loss: 0.0044 - val_mean_absolute_error: 0.0562
# Epoch 89/100
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0039 - mean_absolute_error: 0.0473 - val_loss: 0.0042 - val_mean_absolute_error: 0.0531
# Epoch 90/100
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0036 - mean_absolute_error: 0.0441 - val_loss: 0.0020 - val_mean_absolute_error: 0.0300
# Epoch 91/100
# 55/55 [==============================] - 1s 19ms/step - loss: 0.0039 - mean_absolute_error: 0.0468 - val_loss: 0.0020 - val_mean_absolute_error: 0.0303
# Epoch 92/100
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0041 - mean_absolute_error: 0.0486 - val_loss: 0.0058 - val_mean_absolute_error: 0.0661
# Epoch 93/100
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0044 - mean_absolute_error: 0.0505 - val_loss: 0.0022 - val_mean_absolute_error: 0.0327
# Epoch 94/100
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0033 - mean_absolute_error: 0.0408 - val_loss: 0.0049 - val_mean_absolute_error: 0.0593
# Epoch 95/100
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0036 - mean_absolute_error: 0.0437 - val_loss: 0.0026 - val_mean_absolute_error: 0.0388
# Epoch 96/100
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0044 - mean_absolute_error: 0.0497 - val_loss: 0.0038 - val_mean_absolute_error: 0.0510
# Epoch 97/100
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0052 - mean_absolute_error: 0.0559 - val_loss: 0.0039 - val_mean_absolute_error: 0.0509
# Epoch 98/100
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0039 - mean_absolute_error: 0.0463 - val_loss: 0.0025 - val_mean_absolute_error: 0.0376
# Epoch 99/100
# 55/55 [==============================] - 2s 28ms/step - loss: 0.0044 - mean_absolute_error: 0.0500 - val_loss: 0.0022 - val_mean_absolute_error: 0.0334
# Epoch 100/100
# 55/55 [==============================] - 1s 19ms/step - loss: 0.0036 - mean_absolute_error: 0.0447 - val_loss: 0.0041 - val_mean_absolute_error: 0.0530

# %%
# Check training predictions (use np.exp to transform scaled data back to original scale)

train_predictions = model.predict(X_train1).flatten()

plt.plot(dates_train1, np.exp(train_predictions))
plt.plot(dates_train1, np.exp(y_train1))
plt.xticks(rotation=90)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 55/55 [==============================] - 1s 5ms/step

# %%
# Check scores for val period
score = model.evaluate(X_val1, y_val1, verbose = 0) 

print('Val loss:', score[0]) 
print('Val MAE:', score[1])
# Out:
# Val loss: 0.004112334921956062
# Val MAE: 0.05299874022603035

# %%
# graphed performance of val data in model
val_predictions = model.predict(X_val1).flatten()

plt.plot(dates_val1, np.exp(val_predictions))
plt.plot(dates_val1, np.exp(y_val1))
plt.xticks(rotation=90)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 7/7 [==============================] - 0s 6ms/step

# %%
score = model.evaluate(X_test1, y_test1, verbose = 0) 

print('Test loss:', score[0]) 
print('Test MAE:', score[1])
# Out:
# Test loss: 0.0032465888652950525
# Test MAE: 0.05278531089425087

# %%
#check model against test data
test_predictions = model.predict(X_test1).flatten()

plt.plot(dates_test1, np.exp(test_predictions))
plt.plot(dates_test1, np.exp(y_test1))
plt.xticks(rotation=90)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 7/7 [==============================] - 0s 7ms/step

# %%
# Check r2 score
print('R2 Score: ', r2_score(y_test1, test_predictions))
# Out:
# R2 Score:  0.38971479730248415

# %% [markdown]
# ## Optimization of the Model
#
# - Adjust the initial data used, limited to the last 50% of the data
# - Focus more on recent trends for learning
# - Increase Epochs
# - Slow learning rate

# %%
# Split is changed to begin at 50% of the dataset and continue to the end.
split_1 = .5
split_2 = .89
split_3 = .95


initial_split = int(len(X1) * split_1)
train_split = int(len(X1) * split_2)
test_split = int(len(X1) * split_3)

# %%
#change timeframe

dates_train2, X_train2, y_train2 = dates[initial_split:train_split],X1[initial_split:train_split], y1[initial_split:train_split]
dates_val2, X_val2, y_val2 = dates[train_split:test_split], X1[train_split:test_split], y1[train_split:test_split]
dates_test2, X_test2, y_test2 = dates[test_split:], X1[test_split:], y1[test_split:]
dates_train2.shape, X_train2.shape, y_train2.shape, \
dates_val2.shape, X_val2.shape, y_val2.shape, \
dates_test2.shape, X_test2.shape, y_test2.shape
# Out:
# ((851,),
#  (851, 30),
#  (851,),
#  (130,),
#  (130, 30),
#  (130,),
#  (110,),
#  (110, 30),
#  (110,))

# %%
# Build, compile and fit the new model- increased epochs, smaller learning rate
model2 = Sequential([layers.Input((lookback, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model2.compile(loss='mse',
              optimizer=Adam(learning_rate=0.0001),
              metrics=['mean_absolute_error'])

model2.fit(X_train2, y_train2, validation_data=(X_val2, y_val2), epochs=200)
# Out:
# Epoch 1/200
# 27/27 [==============================] - 3s 37ms/step - loss: 59.2886 - mean_absolute_error: 7.6691 - val_loss: 55.9044 - val_mean_absolute_error: 7.4764
# Epoch 2/200
# 27/27 [==============================] - 0s 17ms/step - loss: 54.9173 - mean_absolute_error: 7.3805 - val_loss: 52.6760 - val_mean_absolute_error: 7.2573
# Epoch 3/200
# 27/27 [==============================] - 0s 17ms/step - loss: 52.2063 - mean_absolute_error: 7.1951 - val_loss: 50.0852 - val_mean_absolute_error: 7.0766
# Epoch 4/200
# 27/27 [==============================] - 0s 16ms/step - loss: 49.4197 - mean_absolute_error: 6.9989 - val_loss: 46.9215 - val_mean_absolute_error: 6.8494
# Epoch 5/200
# 27/27 [==============================] - 0s 17ms/step - loss: 45.5355 - mean_absolute_error: 6.7157 - val_loss: 42.0219 - val_mean_absolute_error: 6.4819
# Epoch 6/200
# 27/27 [==============================] - 0s 18ms/step - loss: 39.5039 - mean_absolute_error: 6.2486 - val_loss: 34.6698 - val_mean_absolute_error: 5.8875
# Epoch 7/200
# 27/27 [==============================] - 0s 18ms/step - loss: 30.3547 - mean_absolute_error: 5.4608 - val_loss: 24.1679 - val_mean_absolute_error: 4.9153
# Epoch 8/200
# 27/27 [==============================] - 0s 18ms/step - loss: 20.2996 - mean_absolute_error: 4.4481 - val_loss: 14.9915 - val_mean_absolute_error: 3.8710
# Epoch 9/200
# 27/27 [==============================] - 1s 19ms/step - loss: 12.1155 - mean_absolute_error: 3.4026 - val_loss: 8.1154 - val_mean_absolute_error: 2.8475
# Epoch 10/200
# 27/27 [==============================] - 0s 17ms/step - loss: 6.2838 - mean_absolute_error: 2.4015 - val_loss: 3.4991 - val_mean_absolute_error: 1.8686
# Epoch 11/200
# 27/27 [==============================] - 0s 18ms/step - loss: 2.6888 - mean_absolute_error: 1.4960 - val_loss: 1.0426 - val_mean_absolute_error: 1.0174
# Epoch 12/200
# 27/27 [==============================] - 1s 21ms/step - loss: 1.0378 - mean_absolute_error: 0.9019 - val_loss: 0.1881 - val_mean_absolute_error: 0.4251
# Epoch 13/200
# 27/27 [==============================] - 1s 43ms/step - loss: 0.5422 - mean_absolute_error: 0.6051 - val_loss: 0.0228 - val_mean_absolute_error: 0.1287
# Epoch 14/200
# 27/27 [==============================] - 1s 35ms/step - loss: 0.4584 - mean_absolute_error: 0.5400 - val_loss: 0.0074 - val_mean_absolute_error: 0.0746
# Epoch 15/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.4471 - mean_absolute_error: 0.5282 - val_loss: 0.0073 - val_mean_absolute_error: 0.0722
# Epoch 16/200
# 27/27 [==============================] - 1s 20ms/step - loss: 0.4430 - mean_absolute_error: 0.5254 - val_loss: 0.0076 - val_mean_absolute_error: 0.0713
# Epoch 17/200
# 27/27 [==============================] - 1s 23ms/step - loss: 0.4380 - mean_absolute_error: 0.5225 - val_loss: 0.0072 - val_mean_absolute_error: 0.0728
# Epoch 18/200
# 27/27 [==============================] - 1s 48ms/step - loss: 0.4285 - mean_absolute_error: 0.5177 - val_loss: 0.0074 - val_mean_absolute_error: 0.0698
# Epoch 19/200
# 27/27 [==============================] - 1s 36ms/step - loss: 0.4112 - mean_absolute_error: 0.5069 - val_loss: 0.0066 - val_mean_absolute_error: 0.0692
# Epoch 20/200
# 27/27 [==============================] - 1s 20ms/step - loss: 0.3761 - mean_absolute_error: 0.4889 - val_loss: 0.0078 - val_mean_absolute_error: 0.0732
# Epoch 21/200
# 27/27 [==============================] - 1s 20ms/step - loss: 0.3272 - mean_absolute_error: 0.4584 - val_loss: 0.0096 - val_mean_absolute_error: 0.0812
# Epoch 22/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.2708 - mean_absolute_error: 0.4188 - val_loss: 0.0078 - val_mean_absolute_error: 0.0741
# Epoch 23/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1503 - mean_absolute_error: 0.3090 - val_loss: 0.0026 - val_mean_absolute_error: 0.0385
# Epoch 24/200
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0548 - mean_absolute_error: 0.1818 - val_loss: 0.0107 - val_mean_absolute_error: 0.0926
# Epoch 25/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0390 - mean_absolute_error: 0.1556 - val_loss: 0.0059 - val_mean_absolute_error: 0.0652
# Epoch 26/200
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0321 - mean_absolute_error: 0.1429 - val_loss: 0.0038 - val_mean_absolute_error: 0.0498
# Epoch 27/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0284 - mean_absolute_error: 0.1325 - val_loss: 0.0058 - val_mean_absolute_error: 0.0637
# Epoch 28/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0262 - mean_absolute_error: 0.1290 - val_loss: 0.0041 - val_mean_absolute_error: 0.0523
# Epoch 29/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0245 - mean_absolute_error: 0.1242 - val_loss: 0.0092 - val_mean_absolute_error: 0.0836
# Epoch 30/200
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0232 - mean_absolute_error: 0.1202 - val_loss: 0.0046 - val_mean_absolute_error: 0.0553
# Epoch 31/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0231 - mean_absolute_error: 0.1210 - val_loss: 0.0037 - val_mean_absolute_error: 0.0500
# Epoch 32/200
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0211 - mean_absolute_error: 0.1150 - val_loss: 0.0037 - val_mean_absolute_error: 0.0494
# Epoch 33/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0206 - mean_absolute_error: 0.1136 - val_loss: 0.0042 - val_mean_absolute_error: 0.0525
# Epoch 34/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0199 - mean_absolute_error: 0.1125 - val_loss: 0.0043 - val_mean_absolute_error: 0.0532
# Epoch 35/200
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0197 - mean_absolute_error: 0.1109 - val_loss: 0.0048 - val_mean_absolute_error: 0.0574
# Epoch 36/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0190 - mean_absolute_error: 0.1095 - val_loss: 0.0032 - val_mean_absolute_error: 0.0466
# Epoch 37/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0185 - mean_absolute_error: 0.1074 - val_loss: 0.0031 - val_mean_absolute_error: 0.0460
# Epoch 38/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0178 - mean_absolute_error: 0.1056 - val_loss: 0.0031 - val_mean_absolute_error: 0.0460
# Epoch 39/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0176 - mean_absolute_error: 0.1053 - val_loss: 0.0031 - val_mean_absolute_error: 0.0461
# Epoch 40/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0170 - mean_absolute_error: 0.1029 - val_loss: 0.0029 - val_mean_absolute_error: 0.0443
# Epoch 41/200
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0166 - mean_absolute_error: 0.1016 - val_loss: 0.0032 - val_mean_absolute_error: 0.0459
# Epoch 42/200
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0165 - mean_absolute_error: 0.1007 - val_loss: 0.0032 - val_mean_absolute_error: 0.0466
# Epoch 43/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0158 - mean_absolute_error: 0.0987 - val_loss: 0.0032 - val_mean_absolute_error: 0.0458
# Epoch 44/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0157 - mean_absolute_error: 0.0997 - val_loss: 0.0050 - val_mean_absolute_error: 0.0593
# Epoch 45/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0152 - mean_absolute_error: 0.0968 - val_loss: 0.0026 - val_mean_absolute_error: 0.0420
# Epoch 46/200
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0157 - mean_absolute_error: 0.0990 - val_loss: 0.0048 - val_mean_absolute_error: 0.0549
# Epoch 47/200
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0145 - mean_absolute_error: 0.0942 - val_loss: 0.0041 - val_mean_absolute_error: 0.0531
# Epoch 48/200
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0142 - mean_absolute_error: 0.0925 - val_loss: 0.0025 - val_mean_absolute_error: 0.0410
# Epoch 49/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0139 - mean_absolute_error: 0.0923 - val_loss: 0.0026 - val_mean_absolute_error: 0.0413
# Epoch 50/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0136 - mean_absolute_error: 0.0903 - val_loss: 0.0027 - val_mean_absolute_error: 0.0419
# Epoch 51/200
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0135 - mean_absolute_error: 0.0903 - val_loss: 0.0027 - val_mean_absolute_error: 0.0422
# Epoch 52/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0129 - mean_absolute_error: 0.0883 - val_loss: 0.0023 - val_mean_absolute_error: 0.0393
# Epoch 53/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0127 - mean_absolute_error: 0.0878 - val_loss: 0.0030 - val_mean_absolute_error: 0.0432
# Epoch 54/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0131 - mean_absolute_error: 0.0894 - val_loss: 0.0023 - val_mean_absolute_error: 0.0389
# Epoch 55/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0121 - mean_absolute_error: 0.0848 - val_loss: 0.0021 - val_mean_absolute_error: 0.0375
# Epoch 56/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0119 - mean_absolute_error: 0.0842 - val_loss: 0.0021 - val_mean_absolute_error: 0.0375
# Epoch 57/200
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0118 - mean_absolute_error: 0.0838 - val_loss: 0.0031 - val_mean_absolute_error: 0.0455
# Epoch 58/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0118 - mean_absolute_error: 0.0836 - val_loss: 0.0024 - val_mean_absolute_error: 0.0397
# Epoch 59/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0114 - mean_absolute_error: 0.0819 - val_loss: 0.0022 - val_mean_absolute_error: 0.0380
# Epoch 60/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0112 - mean_absolute_error: 0.0813 - val_loss: 0.0023 - val_mean_absolute_error: 0.0388
# Epoch 61/200
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0110 - mean_absolute_error: 0.0805 - val_loss: 0.0020 - val_mean_absolute_error: 0.0364
# Epoch 62/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0109 - mean_absolute_error: 0.0800 - val_loss: 0.0021 - val_mean_absolute_error: 0.0368
# Epoch 63/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0109 - mean_absolute_error: 0.0800 - val_loss: 0.0020 - val_mean_absolute_error: 0.0362
# Epoch 64/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0108 - mean_absolute_error: 0.0799 - val_loss: 0.0029 - val_mean_absolute_error: 0.0438
# Epoch 65/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0110 - mean_absolute_error: 0.0804 - val_loss: 0.0028 - val_mean_absolute_error: 0.0434
# Epoch 66/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0105 - mean_absolute_error: 0.0786 - val_loss: 0.0019 - val_mean_absolute_error: 0.0348
# Epoch 67/200
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0104 - mean_absolute_error: 0.0781 - val_loss: 0.0018 - val_mean_absolute_error: 0.0335
# Epoch 68/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0102 - mean_absolute_error: 0.0777 - val_loss: 0.0021 - val_mean_absolute_error: 0.0361
# Epoch 69/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0098 - mean_absolute_error: 0.0759 - val_loss: 0.0021 - val_mean_absolute_error: 0.0366
# Epoch 70/200
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0098 - mean_absolute_error: 0.0751 - val_loss: 0.0018 - val_mean_absolute_error: 0.0343
# Epoch 71/200
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0096 - mean_absolute_error: 0.0749 - val_loss: 0.0019 - val_mean_absolute_error: 0.0340
# Epoch 72/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0097 - mean_absolute_error: 0.0747 - val_loss: 0.0022 - val_mean_absolute_error: 0.0368
# Epoch 73/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0094 - mean_absolute_error: 0.0737 - val_loss: 0.0020 - val_mean_absolute_error: 0.0349
# Epoch 74/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0094 - mean_absolute_error: 0.0735 - val_loss: 0.0017 - val_mean_absolute_error: 0.0325
# Epoch 75/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0090 - mean_absolute_error: 0.0723 - val_loss: 0.0017 - val_mean_absolute_error: 0.0328
# Epoch 76/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0090 - mean_absolute_error: 0.0719 - val_loss: 0.0017 - val_mean_absolute_error: 0.0323
# Epoch 77/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0091 - mean_absolute_error: 0.0723 - val_loss: 0.0017 - val_mean_absolute_error: 0.0318
# Epoch 78/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0093 - mean_absolute_error: 0.0733 - val_loss: 0.0016 - val_mean_absolute_error: 0.0317
# Epoch 79/200
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0091 - mean_absolute_error: 0.0730 - val_loss: 0.0021 - val_mean_absolute_error: 0.0367
# Epoch 80/200
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0087 - mean_absolute_error: 0.0710 - val_loss: 0.0017 - val_mean_absolute_error: 0.0322
# Epoch 81/200
# 27/27 [==============================] - 1s 42ms/step - loss: 0.0086 - mean_absolute_error: 0.0704 - val_loss: 0.0017 - val_mean_absolute_error: 0.0334
# Epoch 82/200
# 27/27 [==============================] - 1s 34ms/step - loss: 0.0084 - mean_absolute_error: 0.0695 - val_loss: 0.0018 - val_mean_absolute_error: 0.0335
# Epoch 83/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0085 - mean_absolute_error: 0.0700 - val_loss: 0.0017 - val_mean_absolute_error: 0.0320
# Epoch 84/200
# 27/27 [==============================] - 1s 26ms/step - loss: 0.0087 - mean_absolute_error: 0.0710 - val_loss: 0.0016 - val_mean_absolute_error: 0.0323
# Epoch 85/200
# 27/27 [==============================] - 1s 24ms/step - loss: 0.0085 - mean_absolute_error: 0.0706 - val_loss: 0.0018 - val_mean_absolute_error: 0.0331
# Epoch 86/200
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0085 - mean_absolute_error: 0.0698 - val_loss: 0.0024 - val_mean_absolute_error: 0.0393
# Epoch 87/200
# 27/27 [==============================] - 1s 18ms/step - loss: 0.0082 - mean_absolute_error: 0.0695 - val_loss: 0.0019 - val_mean_absolute_error: 0.0345
# Epoch 88/200
# 27/27 [==============================] - 1s 18ms/step - loss: 0.0083 - mean_absolute_error: 0.0693 - val_loss: 0.0021 - val_mean_absolute_error: 0.0369
# Epoch 89/200
# 27/27 [==============================] - 1s 26ms/step - loss: 0.0082 - mean_absolute_error: 0.0693 - val_loss: 0.0019 - val_mean_absolute_error: 0.0353
# Epoch 90/200
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0084 - mean_absolute_error: 0.0703 - val_loss: 0.0018 - val_mean_absolute_error: 0.0338
# Epoch 91/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0081 - mean_absolute_error: 0.0684 - val_loss: 0.0015 - val_mean_absolute_error: 0.0304
# Epoch 92/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0081 - mean_absolute_error: 0.0680 - val_loss: 0.0016 - val_mean_absolute_error: 0.0307
# Epoch 93/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0078 - mean_absolute_error: 0.0671 - val_loss: 0.0015 - val_mean_absolute_error: 0.0300
# Epoch 94/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0079 - mean_absolute_error: 0.0670 - val_loss: 0.0018 - val_mean_absolute_error: 0.0336
# Epoch 95/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0077 - mean_absolute_error: 0.0665 - val_loss: 0.0016 - val_mean_absolute_error: 0.0312
# Epoch 96/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0079 - mean_absolute_error: 0.0674 - val_loss: 0.0016 - val_mean_absolute_error: 0.0319
# Epoch 97/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0077 - mean_absolute_error: 0.0669 - val_loss: 0.0023 - val_mean_absolute_error: 0.0378
# Epoch 98/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0076 - mean_absolute_error: 0.0662 - val_loss: 0.0015 - val_mean_absolute_error: 0.0301
# Epoch 99/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0078 - mean_absolute_error: 0.0666 - val_loss: 0.0015 - val_mean_absolute_error: 0.0302
# Epoch 100/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0076 - mean_absolute_error: 0.0664 - val_loss: 0.0023 - val_mean_absolute_error: 0.0388
# Epoch 101/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0076 - mean_absolute_error: 0.0659 - val_loss: 0.0027 - val_mean_absolute_error: 0.0424
# Epoch 102/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0076 - mean_absolute_error: 0.0660 - val_loss: 0.0025 - val_mean_absolute_error: 0.0399
# Epoch 103/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0075 - mean_absolute_error: 0.0659 - val_loss: 0.0016 - val_mean_absolute_error: 0.0314
# Epoch 104/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0074 - mean_absolute_error: 0.0651 - val_loss: 0.0030 - val_mean_absolute_error: 0.0451
# Epoch 105/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0077 - mean_absolute_error: 0.0669 - val_loss: 0.0020 - val_mean_absolute_error: 0.0349
# Epoch 106/200
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0074 - mean_absolute_error: 0.0653 - val_loss: 0.0015 - val_mean_absolute_error: 0.0304
# Epoch 107/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0074 - mean_absolute_error: 0.0649 - val_loss: 0.0015 - val_mean_absolute_error: 0.0297
# Epoch 108/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0074 - mean_absolute_error: 0.0657 - val_loss: 0.0015 - val_mean_absolute_error: 0.0300
# Epoch 109/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0074 - mean_absolute_error: 0.0648 - val_loss: 0.0028 - val_mean_absolute_error: 0.0428
# Epoch 110/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0071 - mean_absolute_error: 0.0629 - val_loss: 0.0021 - val_mean_absolute_error: 0.0372
# Epoch 111/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0073 - mean_absolute_error: 0.0651 - val_loss: 0.0015 - val_mean_absolute_error: 0.0297
# Epoch 112/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0070 - mean_absolute_error: 0.0634 - val_loss: 0.0023 - val_mean_absolute_error: 0.0381
# Epoch 113/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0071 - mean_absolute_error: 0.0634 - val_loss: 0.0016 - val_mean_absolute_error: 0.0316
# Epoch 114/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0072 - mean_absolute_error: 0.0646 - val_loss: 0.0015 - val_mean_absolute_error: 0.0295
# Epoch 115/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0069 - mean_absolute_error: 0.0635 - val_loss: 0.0020 - val_mean_absolute_error: 0.0353
# Epoch 116/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0070 - mean_absolute_error: 0.0638 - val_loss: 0.0019 - val_mean_absolute_error: 0.0340
# Epoch 117/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0070 - mean_absolute_error: 0.0628 - val_loss: 0.0015 - val_mean_absolute_error: 0.0304
# Epoch 118/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0067 - mean_absolute_error: 0.0622 - val_loss: 0.0024 - val_mean_absolute_error: 0.0395
# Epoch 119/200
# 27/27 [==============================] - 1s 24ms/step - loss: 0.0069 - mean_absolute_error: 0.0622 - val_loss: 0.0017 - val_mean_absolute_error: 0.0316
# Epoch 120/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0069 - mean_absolute_error: 0.0629 - val_loss: 0.0032 - val_mean_absolute_error: 0.0470
# Epoch 121/200
# 27/27 [==============================] - 1s 47ms/step - loss: 0.0071 - mean_absolute_error: 0.0634 - val_loss: 0.0016 - val_mean_absolute_error: 0.0321
# Epoch 122/200
# 27/27 [==============================] - 1s 43ms/step - loss: 0.0069 - mean_absolute_error: 0.0627 - val_loss: 0.0015 - val_mean_absolute_error: 0.0297
# Epoch 123/200
# 27/27 [==============================] - 1s 43ms/step - loss: 0.0068 - mean_absolute_error: 0.0625 - val_loss: 0.0016 - val_mean_absolute_error: 0.0311
# Epoch 124/200
# 27/27 [==============================] - 1s 28ms/step - loss: 0.0066 - mean_absolute_error: 0.0613 - val_loss: 0.0021 - val_mean_absolute_error: 0.0362
# Epoch 125/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0070 - mean_absolute_error: 0.0639 - val_loss: 0.0014 - val_mean_absolute_error: 0.0293
# Epoch 126/200
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0069 - mean_absolute_error: 0.0629 - val_loss: 0.0014 - val_mean_absolute_error: 0.0291
# Epoch 127/200
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0066 - mean_absolute_error: 0.0610 - val_loss: 0.0014 - val_mean_absolute_error: 0.0287
# Epoch 128/200
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0065 - mean_absolute_error: 0.0607 - val_loss: 0.0014 - val_mean_absolute_error: 0.0290
# Epoch 129/200
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0069 - mean_absolute_error: 0.0624 - val_loss: 0.0022 - val_mean_absolute_error: 0.0383
# Epoch 130/200
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0068 - mean_absolute_error: 0.0622 - val_loss: 0.0014 - val_mean_absolute_error: 0.0294
# Epoch 131/200
# 27/27 [==============================] - 1s 24ms/step - loss: 0.0064 - mean_absolute_error: 0.0603 - val_loss: 0.0014 - val_mean_absolute_error: 0.0289
# Epoch 132/200
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0066 - mean_absolute_error: 0.0615 - val_loss: 0.0017 - val_mean_absolute_error: 0.0323
# Epoch 133/200
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0065 - mean_absolute_error: 0.0607 - val_loss: 0.0019 - val_mean_absolute_error: 0.0338
# Epoch 134/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0064 - mean_absolute_error: 0.0605 - val_loss: 0.0017 - val_mean_absolute_error: 0.0321
# Epoch 135/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0015 - val_mean_absolute_error: 0.0298
# Epoch 136/200
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0063 - mean_absolute_error: 0.0598 - val_loss: 0.0014 - val_mean_absolute_error: 0.0284
# Epoch 137/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0064 - mean_absolute_error: 0.0604 - val_loss: 0.0017 - val_mean_absolute_error: 0.0323
# Epoch 138/200
# 27/27 [==============================] - 1s 26ms/step - loss: 0.0062 - mean_absolute_error: 0.0596 - val_loss: 0.0015 - val_mean_absolute_error: 0.0294
# Epoch 139/200
# 27/27 [==============================] - 1s 24ms/step - loss: 0.0063 - mean_absolute_error: 0.0602 - val_loss: 0.0015 - val_mean_absolute_error: 0.0302
# Epoch 140/200
# 27/27 [==============================] - 1s 18ms/step - loss: 0.0061 - mean_absolute_error: 0.0585 - val_loss: 0.0014 - val_mean_absolute_error: 0.0291
# Epoch 141/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0061 - mean_absolute_error: 0.0586 - val_loss: 0.0014 - val_mean_absolute_error: 0.0284
# Epoch 142/200
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0014 - val_mean_absolute_error: 0.0288
# Epoch 143/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0066 - mean_absolute_error: 0.0607 - val_loss: 0.0015 - val_mean_absolute_error: 0.0304
# Epoch 144/200
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0061 - mean_absolute_error: 0.0588 - val_loss: 0.0015 - val_mean_absolute_error: 0.0296
# Epoch 145/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0060 - mean_absolute_error: 0.0581 - val_loss: 0.0017 - val_mean_absolute_error: 0.0320
# Epoch 146/200
# 27/27 [==============================] - 1s 40ms/step - loss: 0.0060 - mean_absolute_error: 0.0586 - val_loss: 0.0014 - val_mean_absolute_error: 0.0283
# Epoch 147/200
# 27/27 [==============================] - 1s 38ms/step - loss: 0.0060 - mean_absolute_error: 0.0579 - val_loss: 0.0013 - val_mean_absolute_error: 0.0282
# Epoch 148/200
# 27/27 [==============================] - 1s 36ms/step - loss: 0.0059 - mean_absolute_error: 0.0580 - val_loss: 0.0014 - val_mean_absolute_error: 0.0286
# Epoch 149/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0059 - mean_absolute_error: 0.0577 - val_loss: 0.0013 - val_mean_absolute_error: 0.0282
# Epoch 150/200
# 27/27 [==============================] - 1s 18ms/step - loss: 0.0063 - mean_absolute_error: 0.0608 - val_loss: 0.0014 - val_mean_absolute_error: 0.0283
# Epoch 151/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0060 - mean_absolute_error: 0.0586 - val_loss: 0.0013 - val_mean_absolute_error: 0.0281
# Epoch 152/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0060 - mean_absolute_error: 0.0580 - val_loss: 0.0019 - val_mean_absolute_error: 0.0348
# Epoch 153/200
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0059 - mean_absolute_error: 0.0584 - val_loss: 0.0016 - val_mean_absolute_error: 0.0306
# Epoch 154/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0058 - mean_absolute_error: 0.0565 - val_loss: 0.0017 - val_mean_absolute_error: 0.0323
# Epoch 155/200
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0060 - mean_absolute_error: 0.0583 - val_loss: 0.0025 - val_mean_absolute_error: 0.0409
# Epoch 156/200
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0060 - mean_absolute_error: 0.0586 - val_loss: 0.0019 - val_mean_absolute_error: 0.0338
# Epoch 157/200
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0061 - mean_absolute_error: 0.0589 - val_loss: 0.0014 - val_mean_absolute_error: 0.0287
# Epoch 158/200
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0057 - mean_absolute_error: 0.0570 - val_loss: 0.0020 - val_mean_absolute_error: 0.0361
# Epoch 159/200
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0059 - mean_absolute_error: 0.0581 - val_loss: 0.0013 - val_mean_absolute_error: 0.0282
# Epoch 160/200
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0057 - mean_absolute_error: 0.0565 - val_loss: 0.0017 - val_mean_absolute_error: 0.0325
# Epoch 161/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0058 - mean_absolute_error: 0.0568 - val_loss: 0.0013 - val_mean_absolute_error: 0.0280
# Epoch 162/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0056 - mean_absolute_error: 0.0559 - val_loss: 0.0015 - val_mean_absolute_error: 0.0301
# Epoch 163/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0065 - mean_absolute_error: 0.0612 - val_loss: 0.0013 - val_mean_absolute_error: 0.0279
# Epoch 164/200
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0061 - mean_absolute_error: 0.0593 - val_loss: 0.0017 - val_mean_absolute_error: 0.0319
# Epoch 165/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0057 - mean_absolute_error: 0.0564 - val_loss: 0.0013 - val_mean_absolute_error: 0.0281
# Epoch 166/200
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0056 - mean_absolute_error: 0.0561 - val_loss: 0.0014 - val_mean_absolute_error: 0.0284
# Epoch 167/200
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0056 - mean_absolute_error: 0.0563 - val_loss: 0.0015 - val_mean_absolute_error: 0.0307
# Epoch 168/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0055 - mean_absolute_error: 0.0556 - val_loss: 0.0017 - val_mean_absolute_error: 0.0320
# Epoch 169/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0055 - mean_absolute_error: 0.0557 - val_loss: 0.0014 - val_mean_absolute_error: 0.0284
# Epoch 170/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0054 - mean_absolute_error: 0.0550 - val_loss: 0.0013 - val_mean_absolute_error: 0.0277
# Epoch 171/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0054 - mean_absolute_error: 0.0550 - val_loss: 0.0017 - val_mean_absolute_error: 0.0317
# Epoch 172/200
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0055 - mean_absolute_error: 0.0554 - val_loss: 0.0013 - val_mean_absolute_error: 0.0277
# Epoch 173/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0054 - mean_absolute_error: 0.0555 - val_loss: 0.0014 - val_mean_absolute_error: 0.0283
# Epoch 174/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0058 - mean_absolute_error: 0.0574 - val_loss: 0.0013 - val_mean_absolute_error: 0.0279
# Epoch 175/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0054 - mean_absolute_error: 0.0551 - val_loss: 0.0013 - val_mean_absolute_error: 0.0276
# Epoch 176/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0055 - mean_absolute_error: 0.0558 - val_loss: 0.0033 - val_mean_absolute_error: 0.0492
# Epoch 177/200
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0057 - mean_absolute_error: 0.0571 - val_loss: 0.0021 - val_mean_absolute_error: 0.0372
# Epoch 178/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0053 - mean_absolute_error: 0.0544 - val_loss: 0.0014 - val_mean_absolute_error: 0.0293
# Epoch 179/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0054 - mean_absolute_error: 0.0552 - val_loss: 0.0013 - val_mean_absolute_error: 0.0275
# Epoch 180/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0053 - mean_absolute_error: 0.0543 - val_loss: 0.0013 - val_mean_absolute_error: 0.0275
# Epoch 181/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0053 - mean_absolute_error: 0.0542 - val_loss: 0.0015 - val_mean_absolute_error: 0.0295
# Epoch 182/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0055 - mean_absolute_error: 0.0553 - val_loss: 0.0016 - val_mean_absolute_error: 0.0317
# Epoch 183/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0057 - mean_absolute_error: 0.0569 - val_loss: 0.0014 - val_mean_absolute_error: 0.0283
# Epoch 184/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0052 - mean_absolute_error: 0.0539 - val_loss: 0.0013 - val_mean_absolute_error: 0.0275
# Epoch 185/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0053 - mean_absolute_error: 0.0543 - val_loss: 0.0016 - val_mean_absolute_error: 0.0312
# Epoch 186/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0055 - mean_absolute_error: 0.0561 - val_loss: 0.0014 - val_mean_absolute_error: 0.0284
# Epoch 187/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0052 - mean_absolute_error: 0.0540 - val_loss: 0.0013 - val_mean_absolute_error: 0.0274
# Epoch 188/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0052 - mean_absolute_error: 0.0537 - val_loss: 0.0013 - val_mean_absolute_error: 0.0273
# Epoch 189/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0056 - mean_absolute_error: 0.0563 - val_loss: 0.0026 - val_mean_absolute_error: 0.0424
# Epoch 190/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0059 - mean_absolute_error: 0.0579 - val_loss: 0.0021 - val_mean_absolute_error: 0.0374
# Epoch 191/200
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0051 - mean_absolute_error: 0.0534 - val_loss: 0.0015 - val_mean_absolute_error: 0.0304
# Epoch 192/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0052 - mean_absolute_error: 0.0547 - val_loss: 0.0013 - val_mean_absolute_error: 0.0273
# Epoch 193/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0051 - mean_absolute_error: 0.0529 - val_loss: 0.0014 - val_mean_absolute_error: 0.0283
# Epoch 194/200
# 27/27 [==============================] - 1s 44ms/step - loss: 0.0053 - mean_absolute_error: 0.0552 - val_loss: 0.0019 - val_mean_absolute_error: 0.0347
# Epoch 195/200
# 27/27 [==============================] - 1s 28ms/step - loss: 0.0054 - mean_absolute_error: 0.0550 - val_loss: 0.0013 - val_mean_absolute_error: 0.0271
# Epoch 196/200
# 27/27 [==============================] - 1s 28ms/step - loss: 0.0052 - mean_absolute_error: 0.0542 - val_loss: 0.0016 - val_mean_absolute_error: 0.0312
# Epoch 197/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0051 - mean_absolute_error: 0.0533 - val_loss: 0.0016 - val_mean_absolute_error: 0.0305
# Epoch 198/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0053 - mean_absolute_error: 0.0539 - val_loss: 0.0015 - val_mean_absolute_error: 0.0303
# Epoch 199/200
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0049 - mean_absolute_error: 0.0521 - val_loss: 0.0014 - val_mean_absolute_error: 0.0293
# Epoch 200/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0053 - mean_absolute_error: 0.0545 - val_loss: 0.0023 - val_mean_absolute_error: 0.0400

# %%
#Second model observations
train_predictions2 = model2.predict(X_train2).flatten()

plt.plot(dates_train2, np.exp(train_predictions2))
plt.plot(dates_train2, np.exp(y_train2))
plt.xticks(rotation=90)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 27/27 [==============================] - 1s 5ms/step

# %%
score = model2.evaluate(X_val2, y_val2, verbose = 0) 

print('Val loss:', score[0]) 
print('Val MAE:', score[1])
# Out:
# Val loss: 0.002311200136318803
# Val MAE: 0.04003318399190903

# %%
#Second model observations
val_predictions2 = model2.predict(X_val2).flatten()

plt.plot(dates_val2, np.exp(val_predictions2))
plt.plot(dates_val2, np.exp(y_val2))
plt.xticks(rotation=90)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 5/5 [==============================] - 0s 5ms/step

# %%
#MSAE Score for second model
score = model2.evaluate(X_test2, y_test2, verbose = 0) 

print('Test loss:', score[0]) 
print('Test MAE:', score[1])
# Out:
# Test loss: 0.0018985309870913625
# Test MAE: 0.038702670484781265

# %%
# R2 score for second model
y_pred = model2.predict(X_test2)
print('R2 Score: ', r2_score(y_test2, y_pred))
# Out:
# 4/4 [==============================] - 0s 5ms/step
# R2 Score:  0.5180416981833292

# %%
#Second model observations
test_predictions2 = model2.predict(X_test2).flatten()

plt.plot(dates_test2, np.exp(test_predictions2))
plt.plot(dates_test2,np.exp(y_test2))
plt.xticks(rotation=90)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 4/4 [==============================] - 0s 44ms/step

# %%
# Second optimization. Increased neural density, epochs
model3 = Sequential([layers.Input((lookback, 1)),
                    layers.LSTM(64),
                    layers.Dense(64, activation='relu'),
                    layers.Dense(64, activation='relu'),
                    layers.Dense(1)])

model3.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model3.fit(X_train2, y_train2, validation_data=(X_val2, y_val2), epochs=300)
# Out:
# Epoch 1/300
# 27/27 [==============================] - 3s 39ms/step - loss: 22.5677 - mean_absolute_error: 4.1527 - val_loss: 1.5162 - val_mean_absolute_error: 1.2285
# Epoch 2/300
# 27/27 [==============================] - 0s 18ms/step - loss: 1.2050 - mean_absolute_error: 0.9030 - val_loss: 0.0309 - val_mean_absolute_error: 0.1570
# Epoch 3/300
# 27/27 [==============================] - 0s 17ms/step - loss: 0.4349 - mean_absolute_error: 0.5153 - val_loss: 0.0213 - val_mean_absolute_error: 0.1255
# Epoch 4/300
# 27/27 [==============================] - 1s 21ms/step - loss: 0.3849 - mean_absolute_error: 0.4920 - val_loss: 0.0090 - val_mean_absolute_error: 0.0787
# Epoch 5/300
# 27/27 [==============================] - 1s 20ms/step - loss: 0.1402 - mean_absolute_error: 0.2851 - val_loss: 0.0050 - val_mean_absolute_error: 0.0586
# Epoch 6/300
# 27/27 [==============================] - 1s 24ms/step - loss: 0.0301 - mean_absolute_error: 0.1408 - val_loss: 0.0110 - val_mean_absolute_error: 0.0907
# Epoch 7/300
# 27/27 [==============================] - 1s 25ms/step - loss: 0.0183 - mean_absolute_error: 0.1105 - val_loss: 0.0088 - val_mean_absolute_error: 0.0835
# Epoch 8/300
# 27/27 [==============================] - 1s 32ms/step - loss: 0.0166 - mean_absolute_error: 0.1029 - val_loss: 0.0082 - val_mean_absolute_error: 0.0801
# Epoch 9/300
# 27/27 [==============================] - 1s 28ms/step - loss: 0.0167 - mean_absolute_error: 0.1030 - val_loss: 0.0167 - val_mean_absolute_error: 0.1217
# Epoch 10/300
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0194 - mean_absolute_error: 0.1111 - val_loss: 0.0210 - val_mean_absolute_error: 0.1381
# Epoch 11/300
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0147 - mean_absolute_error: 0.0959 - val_loss: 0.0020 - val_mean_absolute_error: 0.0360
# Epoch 12/300
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0119 - mean_absolute_error: 0.0869 - val_loss: 0.0020 - val_mean_absolute_error: 0.0362
# Epoch 13/300
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0113 - mean_absolute_error: 0.0846 - val_loss: 0.0019 - val_mean_absolute_error: 0.0353
# Epoch 14/300
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0126 - mean_absolute_error: 0.0882 - val_loss: 0.0048 - val_mean_absolute_error: 0.0591
# Epoch 15/300
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0122 - mean_absolute_error: 0.0871 - val_loss: 0.0070 - val_mean_absolute_error: 0.0745
# Epoch 16/300
# 27/27 [==============================] - 1s 25ms/step - loss: 0.0103 - mean_absolute_error: 0.0788 - val_loss: 0.0017 - val_mean_absolute_error: 0.0330
# Epoch 17/300
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0096 - mean_absolute_error: 0.0768 - val_loss: 0.0038 - val_mean_absolute_error: 0.0517
# Epoch 18/300
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0092 - mean_absolute_error: 0.0751 - val_loss: 0.0016 - val_mean_absolute_error: 0.0316
# Epoch 19/300
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0085 - mean_absolute_error: 0.0723 - val_loss: 0.0028 - val_mean_absolute_error: 0.0430
# Epoch 20/300
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0078 - mean_absolute_error: 0.0676 - val_loss: 0.0014 - val_mean_absolute_error: 0.0295
# Epoch 21/300
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0082 - mean_absolute_error: 0.0692 - val_loss: 0.0061 - val_mean_absolute_error: 0.0700
# Epoch 22/300
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0083 - mean_absolute_error: 0.0706 - val_loss: 0.0017 - val_mean_absolute_error: 0.0330
# Epoch 23/300
# 27/27 [==============================] - 1s 18ms/step - loss: 0.0086 - mean_absolute_error: 0.0706 - val_loss: 0.0035 - val_mean_absolute_error: 0.0507
# Epoch 24/300
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0077 - mean_absolute_error: 0.0679 - val_loss: 0.0053 - val_mean_absolute_error: 0.0649
# Epoch 25/300
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0076 - mean_absolute_error: 0.0670 - val_loss: 0.0014 - val_mean_absolute_error: 0.0292
# Epoch 26/300
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0082 - mean_absolute_error: 0.0694 - val_loss: 0.0032 - val_mean_absolute_error: 0.0475
# Epoch 27/300
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0066 - mean_absolute_error: 0.0621 - val_loss: 0.0019 - val_mean_absolute_error: 0.0350
# Epoch 28/300
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0061 - mean_absolute_error: 0.0592 - val_loss: 0.0051 - val_mean_absolute_error: 0.0637
# Epoch 29/300
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0081 - mean_absolute_error: 0.0710 - val_loss: 0.0147 - val_mean_absolute_error: 0.1160
# Epoch 30/300
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0083 - mean_absolute_error: 0.0701 - val_loss: 0.0017 - val_mean_absolute_error: 0.0318
# Epoch 31/300
# 27/27 [==============================] - 1s 24ms/step - loss: 0.0064 - mean_absolute_error: 0.0611 - val_loss: 0.0017 - val_mean_absolute_error: 0.0333
# Epoch 32/300
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0072 - mean_absolute_error: 0.0656 - val_loss: 0.0024 - val_mean_absolute_error: 0.0411
# Epoch 33/300
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0078 - mean_absolute_error: 0.0678 - val_loss: 0.0014 - val_mean_absolute_error: 0.0293
# Epoch 34/300
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0068 - mean_absolute_error: 0.0636 - val_loss: 0.0022 - val_mean_absolute_error: 0.0390
# Epoch 35/300
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0060 - mean_absolute_error: 0.0580 - val_loss: 0.0013 - val_mean_absolute_error: 0.0277
# Epoch 36/300
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0053 - mean_absolute_error: 0.0555 - val_loss: 0.0014 - val_mean_absolute_error: 0.0284
# Epoch 37/300
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0052 - mean_absolute_error: 0.0549 - val_loss: 0.0011 - val_mean_absolute_error: 0.0254
# Epoch 38/300
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0054 - mean_absolute_error: 0.0565 - val_loss: 0.0011 - val_mean_absolute_error: 0.0260
# Epoch 39/300
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0050 - mean_absolute_error: 0.0538 - val_loss: 0.0011 - val_mean_absolute_error: 0.0253
# Epoch 40/300
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0051 - mean_absolute_error: 0.0542 - val_loss: 0.0019 - val_mean_absolute_error: 0.0361
# Epoch 41/300
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0068 - mean_absolute_error: 0.0641 - val_loss: 0.0145 - val_mean_absolute_error: 0.1159
# Epoch 42/300
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0081 - mean_absolute_error: 0.0689 - val_loss: 0.0018 - val_mean_absolute_error: 0.0354
# Epoch 43/300
# 27/27 [==============================] - 1s 18ms/step - loss: 0.0048 - mean_absolute_error: 0.0528 - val_loss: 0.0011 - val_mean_absolute_error: 0.0251
# Epoch 44/300
# 27/27 [==============================] - 1s 18ms/step - loss: 0.0056 - mean_absolute_error: 0.0567 - val_loss: 0.0041 - val_mean_absolute_error: 0.0571
# Epoch 45/300
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0056 - mean_absolute_error: 0.0563 - val_loss: 0.0016 - val_mean_absolute_error: 0.0319
# Epoch 46/300
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0042 - mean_absolute_error: 0.0480 - val_loss: 0.0011 - val_mean_absolute_error: 0.0248
# Epoch 47/300
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0049 - mean_absolute_error: 0.0528 - val_loss: 0.0043 - val_mean_absolute_error: 0.0588
# Epoch 48/300
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0053 - mean_absolute_error: 0.0566 - val_loss: 0.0015 - val_mean_absolute_error: 0.0316
# Epoch 49/300
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0046 - mean_absolute_error: 0.0509 - val_loss: 0.0010 - val_mean_absolute_error: 0.0242
# Epoch 50/300
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0043 - mean_absolute_error: 0.0494 - val_loss: 0.0012 - val_mean_absolute_error: 0.0270
# Epoch 51/300
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0042 - mean_absolute_error: 0.0478 - val_loss: 0.0027 - val_mean_absolute_error: 0.0448
# Epoch 52/300
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0067 - mean_absolute_error: 0.0652 - val_loss: 0.0015 - val_mean_absolute_error: 0.0300
# Epoch 53/300
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0047 - mean_absolute_error: 0.0524 - val_loss: 0.0019 - val_mean_absolute_error: 0.0366
# Epoch 54/300
# 27/27 [==============================] - 1s 26ms/step - loss: 0.0045 - mean_absolute_error: 0.0505 - val_loss: 0.0036 - val_mean_absolute_error: 0.0536
# Epoch 55/300
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0047 - mean_absolute_error: 0.0521 - val_loss: 0.0010 - val_mean_absolute_error: 0.0242
# Epoch 56/300
# 27/27 [==============================] - 1s 18ms/step - loss: 0.0040 - mean_absolute_error: 0.0480 - val_loss: 0.0056 - val_mean_absolute_error: 0.0691
# Epoch 57/300
# 27/27 [==============================] - 1s 18ms/step - loss: 0.0052 - mean_absolute_error: 0.0543 - val_loss: 0.0033 - val_mean_absolute_error: 0.0502
# Epoch 58/300
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0043 - mean_absolute_error: 0.0506 - val_loss: 0.0059 - val_mean_absolute_error: 0.0707
# Epoch 59/300
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0053 - mean_absolute_error: 0.0563 - val_loss: 0.0028 - val_mean_absolute_error: 0.0466
# Epoch 60/300
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0047 - mean_absolute_error: 0.0521 - val_loss: 0.0068 - val_mean_absolute_error: 0.0762
# Epoch 61/300
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0059 - mean_absolute_error: 0.0614 - val_loss: 0.0035 - val_mean_absolute_error: 0.0534
# Epoch 62/300
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0043 - mean_absolute_error: 0.0497 - val_loss: 0.0034 - val_mean_absolute_error: 0.0515
# Epoch 63/300
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0044 - mean_absolute_error: 0.0505 - val_loss: 0.0010 - val_mean_absolute_error: 0.0242
# Epoch 64/300
# 27/27 [==============================] - 1s 18ms/step - loss: 0.0040 - mean_absolute_error: 0.0480 - val_loss: 0.0020 - val_mean_absolute_error: 0.0383
# Epoch 65/300
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0050 - mean_absolute_error: 0.0539 - val_loss: 9.4926e-04 - val_mean_absolute_error: 0.0228
# Epoch 66/300
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0051 - mean_absolute_error: 0.0549 - val_loss: 0.0012 - val_mean_absolute_error: 0.0266
# Epoch 67/300
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0051 - mean_absolute_error: 0.0546 - val_loss: 0.0077 - val_mean_absolute_error: 0.0824
# Epoch 68/300
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0066 - mean_absolute_error: 0.0632 - val_loss: 0.0015 - val_mean_absolute_error: 0.0306
# Epoch 69/300
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0040 - mean_absolute_error: 0.0473 - val_loss: 9.5870e-04 - val_mean_absolute_error: 0.0230
# Epoch 70/300
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0038 - mean_absolute_error: 0.0467 - val_loss: 0.0026 - val_mean_absolute_error: 0.0451
# Epoch 71/300
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0043 - mean_absolute_error: 0.0509 - val_loss: 9.6849e-04 - val_mean_absolute_error: 0.0230
# Epoch 72/300
# 27/27 [==============================] - 1s 18ms/step - loss: 0.0035 - mean_absolute_error: 0.0433 - val_loss: 0.0026 - val_mean_absolute_error: 0.0452
# Epoch 73/300
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0039 - mean_absolute_error: 0.0461 - val_loss: 0.0044 - val_mean_absolute_error: 0.0600
# Epoch 74/300
# 27/27 [==============================] - 1s 18ms/step - loss: 0.0044 - mean_absolute_error: 0.0510 - val_loss: 0.0015 - val_mean_absolute_error: 0.0317
# Epoch 75/300
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0045 - mean_absolute_error: 0.0518 - val_loss: 9.4122e-04 - val_mean_absolute_error: 0.0226
# Epoch 76/300
# 27/27 [==============================] - 1s 18ms/step - loss: 0.0036 - mean_absolute_error: 0.0447 - val_loss: 0.0013 - val_mean_absolute_error: 0.0274
# Epoch 77/300
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0038 - mean_absolute_error: 0.0462 - val_loss: 0.0027 - val_mean_absolute_error: 0.0459
# Epoch 78/300
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0048 - mean_absolute_error: 0.0544 - val_loss: 0.0011 - val_mean_absolute_error: 0.0258
# Epoch 79/300
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0054 - mean_absolute_error: 0.0574 - val_loss: 0.0018 - val_mean_absolute_error: 0.0341
# Epoch 80/300
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0035 - mean_absolute_error: 0.0448 - val_loss: 0.0032 - val_mean_absolute_error: 0.0505
# Epoch 81/300
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0044 - mean_absolute_error: 0.0511 - val_loss: 0.0034 - val_mean_absolute_error: 0.0519
# Epoch 82/300
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0038 - mean_absolute_error: 0.0470 - val_loss: 0.0011 - val_mean_absolute_error: 0.0258
# Epoch 83/300
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0038 - mean_absolute_error: 0.0472 - val_loss: 0.0028 - val_mean_absolute_error: 0.0460
# Epoch 84/300
# 27/27 [==============================] - 1s 18ms/step - loss: 0.0039 - mean_absolute_error: 0.0477 - val_loss: 0.0011 - val_mean_absolute_error: 0.0253
# Epoch 85/300
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0033 - mean_absolute_error: 0.0439 - val_loss: 0.0029 - val_mean_absolute_error: 0.0466
# Epoch 86/300
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0037 - mean_absolute_error: 0.0465 - val_loss: 0.0043 - val_mean_absolute_error: 0.0595
# Epoch 87/300
# 27/27 [==============================] - 1s 18ms/step - loss: 0.0042 - mean_absolute_error: 0.0497 - val_loss: 0.0026 - val_mean_absolute_error: 0.0456
# Epoch 88/300
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0037 - mean_absolute_error: 0.0456 - val_loss: 9.4082e-04 - val_mean_absolute_error: 0.0227
# Epoch 89/300
# 27/27 [==============================] - 1s 18ms/step - loss: 0.0036 - mean_absolute_error: 0.0450 - val_loss: 0.0013 - val_mean_absolute_error: 0.0284
# Epoch 90/300
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0054 - mean_absolute_error: 0.0584 - val_loss: 0.0010 - val_mean_absolute_error: 0.0244
# Epoch 91/300
# 27/27 [==============================] - 1s 18ms/step - loss: 0.0042 - mean_absolute_error: 0.0498 - val_loss: 0.0015 - val_mean_absolute_error: 0.0320
# Epoch 92/300
# 27/27 [==============================] - 1s 18ms/step - loss: 0.0038 - mean_absolute_error: 0.0462 - val_loss: 0.0017 - val_mean_absolute_error: 0.0327
# Epoch 93/300
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0036 - mean_absolute_error: 0.0455 - val_loss: 0.0016 - val_mean_absolute_error: 0.0335
# Epoch 94/300
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0040 - mean_absolute_error: 0.0483 - val_loss: 9.5768e-04 - val_mean_absolute_error: 0.0233
# Epoch 95/300
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0036 - mean_absolute_error: 0.0451 - val_loss: 8.7753e-04 - val_mean_absolute_error: 0.0217
# Epoch 96/300
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0041 - mean_absolute_error: 0.0482 - val_loss: 9.3586e-04 - val_mean_absolute_error: 0.0228
# Epoch 97/300
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0033 - mean_absolute_error: 0.0443 - val_loss: 0.0030 - val_mean_absolute_error: 0.0493
# Epoch 98/300
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0037 - mean_absolute_error: 0.0451 - val_loss: 0.0026 - val_mean_absolute_error: 0.0457
# Epoch 99/300
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0037 - mean_absolute_error: 0.0464 - val_loss: 9.9823e-04 - val_mean_absolute_error: 0.0239
# Epoch 100/300
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0054 - mean_absolute_error: 0.0575 - val_loss: 0.0033 - val_mean_absolute_error: 0.0506
# Epoch 101/300
# 27/27 [==============================] - 1s 18ms/step - loss: 0.0035 - mean_absolute_error: 0.0450 - val_loss: 0.0013 - val_mean_absolute_error: 0.0282
# Epoch 102/300
# 27/27 [==============================] - 1s 18ms/step - loss: 0.0042 - mean_absolute_error: 0.0492 - val_loss: 0.0020 - val_mean_absolute_error: 0.0387
# Epoch 103/300
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0043 - mean_absolute_error: 0.0509 - val_loss: 0.0015 - val_mean_absolute_error: 0.0315
# Epoch 104/300
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0038 - mean_absolute_error: 0.0469 - val_loss: 9.1936e-04 - val_mean_absolute_error: 0.0225
# Epoch 105/300
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0035 - mean_absolute_error: 0.0446 - val_loss: 0.0026 - val_mean_absolute_error: 0.0452
# Epoch 106/300
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0035 - mean_absolute_error: 0.0438 - val_loss: 0.0011 - val_mean_absolute_error: 0.0251
# Epoch 107/300
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0036 - mean_absolute_error: 0.0459 - val_loss: 0.0014 - val_mean_absolute_error: 0.0310
# Epoch 108/300
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0036 - mean_absolute_error: 0.0468 - val_loss: 8.5327e-04 - val_mean_absolute_error: 0.0213
# Epoch 109/300
# 27/27 [==============================] - 1s 18ms/step - loss: 0.0041 - mean_absolute_error: 0.0488 - val_loss: 0.0023 - val_mean_absolute_error: 0.0421
# Epoch 110/300
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0039 - mean_absolute_error: 0.0477 - val_loss: 0.0048 - val_mean_absolute_error: 0.0640
# Epoch 111/300
# 27/27 [==============================] - 1s 18ms/step - loss: 0.0035 - mean_absolute_error: 0.0456 - val_loss: 0.0015 - val_mean_absolute_error: 0.0309
# Epoch 112/300
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0040 - mean_absolute_error: 0.0483 - val_loss: 0.0011 - val_mean_absolute_error: 0.0257
# Epoch 113/300
# 27/27 [==============================] - 1s 18ms/step - loss: 0.0051 - mean_absolute_error: 0.0577 - val_loss: 0.0015 - val_mean_absolute_error: 0.0319
# Epoch 114/300
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0047 - mean_absolute_error: 0.0537 - val_loss: 0.0016 - val_mean_absolute_error: 0.0332
# Epoch 115/300
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0048 - mean_absolute_error: 0.0540 - val_loss: 0.0011 - val_mean_absolute_error: 0.0270
# Epoch 116/300
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0031 - mean_absolute_error: 0.0414 - val_loss: 8.4505e-04 - val_mean_absolute_error: 0.0213
# Epoch 117/300
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0032 - mean_absolute_error: 0.0425 - val_loss: 9.1476e-04 - val_mean_absolute_error: 0.0225
# Epoch 118/300
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0035 - mean_absolute_error: 0.0440 - val_loss: 8.2688e-04 - val_mean_absolute_error: 0.0209
# Epoch 119/300
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0042 - mean_absolute_error: 0.0509 - val_loss: 0.0042 - val_mean_absolute_error: 0.0587
# Epoch 120/300
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0038 - mean_absolute_error: 0.0469 - val_loss: 8.2480e-04 - val_mean_absolute_error: 0.0209
# Epoch 121/300
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0038 - mean_absolute_error: 0.0469 - val_loss: 0.0015 - val_mean_absolute_error: 0.0319
# Epoch 122/300
# 27/27 [==============================] - 1s 51ms/step - loss: 0.0060 - mean_absolute_error: 0.0614 - val_loss: 0.0085 - val_mean_absolute_error: 0.0875
# Epoch 123/300
# 27/27 [==============================] - 1s 53ms/step - loss: 0.0054 - mean_absolute_error: 0.0577 - val_loss: 8.7134e-04 - val_mean_absolute_error: 0.0220
# Epoch 124/300
# 27/27 [==============================] - 1s 35ms/step - loss: 0.0033 - mean_absolute_error: 0.0435 - val_loss: 8.6464e-04 - val_mean_absolute_error: 0.0219
# Epoch 125/300
# 27/27 [==============================] - 1s 25ms/step - loss: 0.0029 - mean_absolute_error: 0.0404 - val_loss: 0.0012 - val_mean_absolute_error: 0.0261
# Epoch 126/300
# 27/27 [==============================] - 1s 44ms/step - loss: 0.0044 - mean_absolute_error: 0.0513 - val_loss: 0.0017 - val_mean_absolute_error: 0.0333
# Epoch 127/300
# 27/27 [==============================] - 1s 37ms/step - loss: 0.0031 - mean_absolute_error: 0.0419 - val_loss: 0.0021 - val_mean_absolute_error: 0.0392
# Epoch 128/300
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0037 - mean_absolute_error: 0.0467 - val_loss: 0.0026 - val_mean_absolute_error: 0.0443
# Epoch 129/300
# 27/27 [==============================] - 1s 24ms/step - loss: 0.0036 - mean_absolute_error: 0.0460 - val_loss: 0.0011 - val_mean_absolute_error: 0.0261
# Epoch 130/300
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0043 - mean_absolute_error: 0.0499 - val_loss: 8.4913e-04 - val_mean_absolute_error: 0.0216
# Epoch 131/300
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0034 - mean_absolute_error: 0.0440 - val_loss: 0.0020 - val_mean_absolute_error: 0.0380
# Epoch 132/300
# 27/27 [==============================] - 1s 42ms/step - loss: 0.0039 - mean_absolute_error: 0.0478 - val_loss: 8.4346e-04 - val_mean_absolute_error: 0.0213
# Epoch 133/300
# 27/27 [==============================] - 1s 37ms/step - loss: 0.0035 - mean_absolute_error: 0.0450 - val_loss: 8.1988e-04 - val_mean_absolute_error: 0.0208
# Epoch 134/300
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0039 - mean_absolute_error: 0.0492 - val_loss: 8.8262e-04 - val_mean_absolute_error: 0.0226
# Epoch 135/300
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0033 - mean_absolute_error: 0.0436 - val_loss: 0.0067 - val_mean_absolute_error: 0.0768
# Epoch 136/300
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0034 - mean_absolute_error: 0.0443 - val_loss: 8.8409e-04 - val_mean_absolute_error: 0.0226
# Epoch 137/300
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0029 - mean_absolute_error: 0.0399 - val_loss: 9.6231e-04 - val_mean_absolute_error: 0.0235
# Epoch 138/300
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0038 - mean_absolute_error: 0.0471 - val_loss: 0.0063 - val_mean_absolute_error: 0.0745
# Epoch 139/300
# 27/27 [==============================] - 1s 26ms/step - loss: 0.0070 - mean_absolute_error: 0.0689 - val_loss: 9.3820e-04 - val_mean_absolute_error: 0.0232
# Epoch 140/300
# 27/27 [==============================] - 1s 26ms/step - loss: 0.0048 - mean_absolute_error: 0.0546 - val_loss: 0.0066 - val_mean_absolute_error: 0.0762
# Epoch 141/300
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0066 - mean_absolute_error: 0.0660 - val_loss: 0.0016 - val_mean_absolute_error: 0.0323
# Epoch 142/300
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0037 - mean_absolute_error: 0.0461 - val_loss: 0.0077 - val_mean_absolute_error: 0.0828
# Epoch 143/300
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0037 - mean_absolute_error: 0.0460 - val_loss: 0.0022 - val_mean_absolute_error: 0.0407
# Epoch 144/300
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0035 - mean_absolute_error: 0.0442 - val_loss: 8.0899e-04 - val_mean_absolute_error: 0.0205
# Epoch 145/300
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0044 - mean_absolute_error: 0.0502 - val_loss: 0.0028 - val_mean_absolute_error: 0.0463
# Epoch 146/300
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0053 - mean_absolute_error: 0.0580 - val_loss: 0.0089 - val_mean_absolute_error: 0.0901
# Epoch 147/300
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0047 - mean_absolute_error: 0.0533 - val_loss: 8.5642e-04 - val_mean_absolute_error: 0.0215
# Epoch 148/300
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0031 - mean_absolute_error: 0.0422 - val_loss: 0.0019 - val_mean_absolute_error: 0.0372
# Epoch 149/300
# 27/27 [==============================] - 1s 43ms/step - loss: 0.0044 - mean_absolute_error: 0.0527 - val_loss: 0.0025 - val_mean_absolute_error: 0.0449
# Epoch 150/300
# 27/27 [==============================] - 1s 37ms/step - loss: 0.0036 - mean_absolute_error: 0.0454 - val_loss: 0.0012 - val_mean_absolute_error: 0.0275
# Epoch 151/300
# 27/27 [==============================] - 1s 46ms/step - loss: 0.0055 - mean_absolute_error: 0.0579 - val_loss: 7.9718e-04 - val_mean_absolute_error: 0.0207
# Epoch 152/300
# 27/27 [==============================] - 1s 39ms/step - loss: 0.0033 - mean_absolute_error: 0.0434 - val_loss: 0.0024 - val_mean_absolute_error: 0.0419
# Epoch 153/300
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0047 - mean_absolute_error: 0.0547 - val_loss: 0.0014 - val_mean_absolute_error: 0.0315
# Epoch 154/300
# 27/27 [==============================] - 1s 35ms/step - loss: 0.0031 - mean_absolute_error: 0.0410 - val_loss: 0.0011 - val_mean_absolute_error: 0.0272
# Epoch 155/300
# 27/27 [==============================] - 1s 26ms/step - loss: 0.0038 - mean_absolute_error: 0.0479 - val_loss: 0.0023 - val_mean_absolute_error: 0.0407
# Epoch 156/300
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0042 - mean_absolute_error: 0.0510 - val_loss: 0.0013 - val_mean_absolute_error: 0.0294
# Epoch 157/300
# 27/27 [==============================] - 1s 35ms/step - loss: 0.0035 - mean_absolute_error: 0.0451 - val_loss: 9.7320e-04 - val_mean_absolute_error: 0.0237
# Epoch 158/300
# 27/27 [==============================] - 1s 43ms/step - loss: 0.0030 - mean_absolute_error: 0.0408 - val_loss: 0.0035 - val_mean_absolute_error: 0.0534
# Epoch 159/300
# 27/27 [==============================] - 1s 42ms/step - loss: 0.0058 - mean_absolute_error: 0.0609 - val_loss: 0.0014 - val_mean_absolute_error: 0.0313
# Epoch 160/300
# 27/27 [==============================] - 1s 35ms/step - loss: 0.0037 - mean_absolute_error: 0.0469 - val_loss: 0.0020 - val_mean_absolute_error: 0.0384
# Epoch 161/300
# 27/27 [==============================] - 1s 36ms/step - loss: 0.0031 - mean_absolute_error: 0.0412 - val_loss: 0.0038 - val_mean_absolute_error: 0.0568
# Epoch 162/300
# 27/27 [==============================] - 1s 32ms/step - loss: 0.0033 - mean_absolute_error: 0.0438 - val_loss: 0.0029 - val_mean_absolute_error: 0.0470
# Epoch 163/300
# 27/27 [==============================] - 1s 36ms/step - loss: 0.0034 - mean_absolute_error: 0.0437 - val_loss: 8.3791e-04 - val_mean_absolute_error: 0.0217
# Epoch 164/300
# 27/27 [==============================] - 1s 28ms/step - loss: 0.0033 - mean_absolute_error: 0.0430 - val_loss: 0.0044 - val_mean_absolute_error: 0.0603
# Epoch 165/300
# 27/27 [==============================] - 1s 39ms/step - loss: 0.0031 - mean_absolute_error: 0.0416 - val_loss: 8.1759e-04 - val_mean_absolute_error: 0.0208
# Epoch 166/300
# 27/27 [==============================] - 1s 25ms/step - loss: 0.0034 - mean_absolute_error: 0.0456 - val_loss: 0.0021 - val_mean_absolute_error: 0.0402
# Epoch 167/300
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0055 - mean_absolute_error: 0.0606 - val_loss: 0.0024 - val_mean_absolute_error: 0.0420
# Epoch 168/300
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0035 - mean_absolute_error: 0.0444 - val_loss: 9.8842e-04 - val_mean_absolute_error: 0.0238
# Epoch 169/300
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0040 - mean_absolute_error: 0.0493 - val_loss: 8.0477e-04 - val_mean_absolute_error: 0.0211
# Epoch 170/300
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0032 - mean_absolute_error: 0.0424 - val_loss: 0.0020 - val_mean_absolute_error: 0.0378
# Epoch 171/300
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0032 - mean_absolute_error: 0.0424 - val_loss: 0.0018 - val_mean_absolute_error: 0.0357
# Epoch 172/300
# 27/27 [==============================] - 1s 25ms/step - loss: 0.0030 - mean_absolute_error: 0.0417 - val_loss: 0.0014 - val_mean_absolute_error: 0.0298
# Epoch 173/300
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0036 - mean_absolute_error: 0.0458 - val_loss: 8.0217e-04 - val_mean_absolute_error: 0.0210
# Epoch 174/300
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0029 - mean_absolute_error: 0.0394 - val_loss: 0.0021 - val_mean_absolute_error: 0.0393
# Epoch 175/300
# 27/27 [==============================] - 1s 29ms/step - loss: 0.0042 - mean_absolute_error: 0.0514 - val_loss: 0.0013 - val_mean_absolute_error: 0.0290
# Epoch 176/300
# 27/27 [==============================] - 1s 34ms/step - loss: 0.0038 - mean_absolute_error: 0.0466 - val_loss: 0.0013 - val_mean_absolute_error: 0.0289
# Epoch 177/300
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0040 - mean_absolute_error: 0.0500 - val_loss: 0.0012 - val_mean_absolute_error: 0.0288
# Epoch 178/300
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0043 - mean_absolute_error: 0.0511 - val_loss: 0.0025 - val_mean_absolute_error: 0.0438
# Epoch 179/300
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0061 - mean_absolute_error: 0.0644 - val_loss: 0.0011 - val_mean_absolute_error: 0.0251
# Epoch 180/300
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0032 - mean_absolute_error: 0.0426 - val_loss: 0.0024 - val_mean_absolute_error: 0.0436
# Epoch 181/300
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0035 - mean_absolute_error: 0.0444 - val_loss: 7.8353e-04 - val_mean_absolute_error: 0.0202
# Epoch 182/300
# 27/27 [==============================] - 1s 24ms/step - loss: 0.0041 - mean_absolute_error: 0.0491 - val_loss: 0.0043 - val_mean_absolute_error: 0.0607
# Epoch 183/300
# 27/27 [==============================] - 1s 47ms/step - loss: 0.0033 - mean_absolute_error: 0.0440 - val_loss: 0.0027 - val_mean_absolute_error: 0.0456
# Epoch 184/300
# 27/27 [==============================] - 1s 39ms/step - loss: 0.0034 - mean_absolute_error: 0.0448 - val_loss: 0.0015 - val_mean_absolute_error: 0.0325
# Epoch 185/300
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0032 - mean_absolute_error: 0.0431 - val_loss: 0.0014 - val_mean_absolute_error: 0.0300
# Epoch 186/300
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0054 - mean_absolute_error: 0.0587 - val_loss: 0.0110 - val_mean_absolute_error: 0.1009
# Epoch 187/300
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0055 - mean_absolute_error: 0.0598 - val_loss: 0.0173 - val_mean_absolute_error: 0.1286
# Epoch 188/300
# 27/27 [==============================] - 1s 25ms/step - loss: 0.0072 - mean_absolute_error: 0.0688 - val_loss: 0.0063 - val_mean_absolute_error: 0.0745
# Epoch 189/300
# 27/27 [==============================] - 1s 24ms/step - loss: 0.0034 - mean_absolute_error: 0.0441 - val_loss: 8.6508e-04 - val_mean_absolute_error: 0.0227
# Epoch 190/300
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0051 - mean_absolute_error: 0.0553 - val_loss: 0.0057 - val_mean_absolute_error: 0.0705
# Epoch 191/300
# 27/27 [==============================] - 1s 36ms/step - loss: 0.0040 - mean_absolute_error: 0.0490 - val_loss: 0.0015 - val_mean_absolute_error: 0.0329
# Epoch 192/300
# 27/27 [==============================] - 1s 34ms/step - loss: 0.0030 - mean_absolute_error: 0.0406 - val_loss: 0.0011 - val_mean_absolute_error: 0.0267
# Epoch 193/300
# 27/27 [==============================] - 1s 25ms/step - loss: 0.0039 - mean_absolute_error: 0.0489 - val_loss: 0.0058 - val_mean_absolute_error: 0.0714
# Epoch 194/300
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0040 - mean_absolute_error: 0.0481 - val_loss: 0.0021 - val_mean_absolute_error: 0.0401
# Epoch 195/300
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0045 - mean_absolute_error: 0.0531 - val_loss: 8.1298e-04 - val_mean_absolute_error: 0.0208
# Epoch 196/300
# 27/27 [==============================] - 1s 31ms/step - loss: 0.0057 - mean_absolute_error: 0.0595 - val_loss: 8.8225e-04 - val_mean_absolute_error: 0.0232
# Epoch 197/300
# 27/27 [==============================] - 1s 28ms/step - loss: 0.0037 - mean_absolute_error: 0.0474 - val_loss: 0.0012 - val_mean_absolute_error: 0.0286
# Epoch 198/300
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0034 - mean_absolute_error: 0.0439 - val_loss: 0.0016 - val_mean_absolute_error: 0.0342
# Epoch 199/300
# 27/27 [==============================] - 1s 25ms/step - loss: 0.0039 - mean_absolute_error: 0.0483 - val_loss: 0.0018 - val_mean_absolute_error: 0.0356
# Epoch 200/300
# 27/27 [==============================] - 2s 60ms/step - loss: 0.0037 - mean_absolute_error: 0.0470 - val_loss: 0.0040 - val_mean_absolute_error: 0.0575
# Epoch 201/300
# 27/27 [==============================] - 1s 35ms/step - loss: 0.0051 - mean_absolute_error: 0.0570 - val_loss: 7.8385e-04 - val_mean_absolute_error: 0.0202
# Epoch 202/300
# 27/27 [==============================] - 1s 24ms/step - loss: 0.0041 - mean_absolute_error: 0.0489 - val_loss: 0.0020 - val_mean_absolute_error: 0.0376
# Epoch 203/300
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0031 - mean_absolute_error: 0.0427 - val_loss: 8.2271e-04 - val_mean_absolute_error: 0.0218
# Epoch 204/300
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0032 - mean_absolute_error: 0.0419 - val_loss: 0.0033 - val_mean_absolute_error: 0.0522
# Epoch 205/300
# 27/27 [==============================] - 1s 24ms/step - loss: 0.0051 - mean_absolute_error: 0.0577 - val_loss: 0.0135 - val_mean_absolute_error: 0.1126
# Epoch 206/300
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0073 - mean_absolute_error: 0.0695 - val_loss: 0.0119 - val_mean_absolute_error: 0.1055
# Epoch 207/300
# 27/27 [==============================] - 1s 28ms/step - loss: 0.0047 - mean_absolute_error: 0.0530 - val_loss: 0.0016 - val_mean_absolute_error: 0.0331
# Epoch 208/300
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0037 - mean_absolute_error: 0.0467 - val_loss: 0.0017 - val_mean_absolute_error: 0.0336
# Epoch 209/300
# 27/27 [==============================] - 1s 45ms/step - loss: 0.0068 - mean_absolute_error: 0.0676 - val_loss: 7.8090e-04 - val_mean_absolute_error: 0.0202
# Epoch 210/300
# 27/27 [==============================] - 1s 25ms/step - loss: 0.0038 - mean_absolute_error: 0.0480 - val_loss: 0.0010 - val_mean_absolute_error: 0.0258
# Epoch 211/300
# 27/27 [==============================] - 1s 28ms/step - loss: 0.0039 - mean_absolute_error: 0.0474 - val_loss: 8.1895e-04 - val_mean_absolute_error: 0.0210
# Epoch 212/300
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0032 - mean_absolute_error: 0.0430 - val_loss: 0.0023 - val_mean_absolute_error: 0.0408
# Epoch 213/300
# 27/27 [==============================] - 1s 26ms/step - loss: 0.0037 - mean_absolute_error: 0.0470 - val_loss: 9.5307e-04 - val_mean_absolute_error: 0.0232
# Epoch 214/300
# 27/27 [==============================] - 1s 24ms/step - loss: 0.0032 - mean_absolute_error: 0.0428 - val_loss: 8.1286e-04 - val_mean_absolute_error: 0.0207
# Epoch 215/300
# 27/27 [==============================] - 1s 25ms/step - loss: 0.0030 - mean_absolute_error: 0.0410 - val_loss: 0.0016 - val_mean_absolute_error: 0.0325
# Epoch 216/300
# 27/27 [==============================] - 1s 37ms/step - loss: 0.0033 - mean_absolute_error: 0.0435 - val_loss: 0.0012 - val_mean_absolute_error: 0.0268
# Epoch 217/300
# 27/27 [==============================] - 1s 52ms/step - loss: 0.0046 - mean_absolute_error: 0.0524 - val_loss: 0.0117 - val_mean_absolute_error: 0.1047
# Epoch 218/300
# 27/27 [==============================] - 1s 50ms/step - loss: 0.0069 - mean_absolute_error: 0.0674 - val_loss: 8.9676e-04 - val_mean_absolute_error: 0.0236
# Epoch 219/300
# 27/27 [==============================] - 2s 58ms/step - loss: 0.0034 - mean_absolute_error: 0.0445 - val_loss: 0.0039 - val_mean_absolute_error: 0.0568
# Epoch 220/300
# 27/27 [==============================] - 2s 69ms/step - loss: 0.0045 - mean_absolute_error: 0.0532 - val_loss: 7.6544e-04 - val_mean_absolute_error: 0.0201
# Epoch 221/300
# 27/27 [==============================] - 1s 38ms/step - loss: 0.0039 - mean_absolute_error: 0.0485 - val_loss: 8.9995e-04 - val_mean_absolute_error: 0.0237
# Epoch 222/300
# 27/27 [==============================] - 1s 55ms/step - loss: 0.0034 - mean_absolute_error: 0.0448 - val_loss: 7.9360e-04 - val_mean_absolute_error: 0.0206
# Epoch 223/300
# 27/27 [==============================] - 1s 46ms/step - loss: 0.0032 - mean_absolute_error: 0.0433 - val_loss: 8.8980e-04 - val_mean_absolute_error: 0.0221
# Epoch 224/300
# 27/27 [==============================] - 1s 48ms/step - loss: 0.0035 - mean_absolute_error: 0.0453 - val_loss: 0.0052 - val_mean_absolute_error: 0.0668
# Epoch 225/300
# 27/27 [==============================] - 1s 44ms/step - loss: 0.0037 - mean_absolute_error: 0.0465 - val_loss: 8.5294e-04 - val_mean_absolute_error: 0.0227
# Epoch 226/300
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0033 - mean_absolute_error: 0.0429 - val_loss: 0.0015 - val_mean_absolute_error: 0.0313
# Epoch 227/300
# 27/27 [==============================] - 1s 31ms/step - loss: 0.0048 - mean_absolute_error: 0.0552 - val_loss: 0.0023 - val_mean_absolute_error: 0.0423
# Epoch 228/300
# 27/27 [==============================] - 1s 35ms/step - loss: 0.0040 - mean_absolute_error: 0.0497 - val_loss: 9.5722e-04 - val_mean_absolute_error: 0.0248
# Epoch 229/300
# 27/27 [==============================] - 1s 29ms/step - loss: 0.0034 - mean_absolute_error: 0.0449 - val_loss: 0.0037 - val_mean_absolute_error: 0.0550
# Epoch 230/300
# 27/27 [==============================] - 1s 28ms/step - loss: 0.0034 - mean_absolute_error: 0.0438 - val_loss: 0.0014 - val_mean_absolute_error: 0.0312
# Epoch 231/300
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0035 - mean_absolute_error: 0.0449 - val_loss: 8.4902e-04 - val_mean_absolute_error: 0.0225
# Epoch 232/300
# 27/27 [==============================] - 1s 37ms/step - loss: 0.0038 - mean_absolute_error: 0.0475 - val_loss: 0.0068 - val_mean_absolute_error: 0.0780
# Epoch 233/300
# 27/27 [==============================] - 1s 35ms/step - loss: 0.0046 - mean_absolute_error: 0.0542 - val_loss: 8.9117e-04 - val_mean_absolute_error: 0.0235
# Epoch 234/300
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0053 - mean_absolute_error: 0.0584 - val_loss: 8.2965e-04 - val_mean_absolute_error: 0.0221
# Epoch 235/300
# 27/27 [==============================] - 1s 36ms/step - loss: 0.0040 - mean_absolute_error: 0.0489 - val_loss: 0.0029 - val_mean_absolute_error: 0.0475
# Epoch 236/300
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0042 - mean_absolute_error: 0.0503 - val_loss: 0.0049 - val_mean_absolute_error: 0.0650
# Epoch 237/300
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0047 - mean_absolute_error: 0.0551 - val_loss: 8.0622e-04 - val_mean_absolute_error: 0.0209
# Epoch 238/300
# 27/27 [==============================] - 1s 26ms/step - loss: 0.0034 - mean_absolute_error: 0.0451 - val_loss: 0.0012 - val_mean_absolute_error: 0.0291
# Epoch 239/300
# 27/27 [==============================] - 1s 38ms/step - loss: 0.0030 - mean_absolute_error: 0.0407 - val_loss: 0.0025 - val_mean_absolute_error: 0.0440
# Epoch 240/300
# 27/27 [==============================] - 1s 26ms/step - loss: 0.0049 - mean_absolute_error: 0.0557 - val_loss: 7.6691e-04 - val_mean_absolute_error: 0.0202
# Epoch 241/300
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0043 - mean_absolute_error: 0.0509 - val_loss: 8.8838e-04 - val_mean_absolute_error: 0.0235
# Epoch 242/300
# 27/27 [==============================] - 1s 24ms/step - loss: 0.0029 - mean_absolute_error: 0.0408 - val_loss: 0.0041 - val_mean_absolute_error: 0.0586
# Epoch 243/300
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0058 - mean_absolute_error: 0.0611 - val_loss: 0.0055 - val_mean_absolute_error: 0.0691
# Epoch 244/300
# 27/27 [==============================] - 1s 28ms/step - loss: 0.0051 - mean_absolute_error: 0.0564 - val_loss: 0.0015 - val_mean_absolute_error: 0.0311
# Epoch 245/300
# 27/27 [==============================] - 1s 25ms/step - loss: 0.0063 - mean_absolute_error: 0.0636 - val_loss: 0.0047 - val_mean_absolute_error: 0.0631
# Epoch 246/300
# 27/27 [==============================] - 1s 25ms/step - loss: 0.0041 - mean_absolute_error: 0.0491 - val_loss: 0.0012 - val_mean_absolute_error: 0.0271
# Epoch 247/300
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0030 - mean_absolute_error: 0.0412 - val_loss: 0.0020 - val_mean_absolute_error: 0.0391
# Epoch 248/300
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0030 - mean_absolute_error: 0.0409 - val_loss: 0.0012 - val_mean_absolute_error: 0.0265
# Epoch 249/300
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0031 - mean_absolute_error: 0.0419 - val_loss: 0.0010 - val_mean_absolute_error: 0.0242
# Epoch 250/300
# 27/27 [==============================] - 1s 32ms/step - loss: 0.0034 - mean_absolute_error: 0.0449 - val_loss: 0.0021 - val_mean_absolute_error: 0.0396
# Epoch 251/300
# 27/27 [==============================] - 1s 25ms/step - loss: 0.0042 - mean_absolute_error: 0.0513 - val_loss: 7.6499e-04 - val_mean_absolute_error: 0.0203
# Epoch 252/300
# 27/27 [==============================] - 1s 38ms/step - loss: 0.0035 - mean_absolute_error: 0.0460 - val_loss: 0.0017 - val_mean_absolute_error: 0.0354
# Epoch 253/300
# 27/27 [==============================] - 1s 25ms/step - loss: 0.0035 - mean_absolute_error: 0.0451 - val_loss: 7.9685e-04 - val_mean_absolute_error: 0.0213
# Epoch 254/300
# 27/27 [==============================] - 1s 28ms/step - loss: 0.0043 - mean_absolute_error: 0.0506 - val_loss: 0.0012 - val_mean_absolute_error: 0.0276
# Epoch 255/300
# 27/27 [==============================] - 1s 28ms/step - loss: 0.0041 - mean_absolute_error: 0.0492 - val_loss: 0.0013 - val_mean_absolute_error: 0.0285
# Epoch 256/300
# 27/27 [==============================] - 1s 28ms/step - loss: 0.0039 - mean_absolute_error: 0.0490 - val_loss: 8.2743e-04 - val_mean_absolute_error: 0.0212
# Epoch 257/300
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0030 - mean_absolute_error: 0.0414 - val_loss: 9.2238e-04 - val_mean_absolute_error: 0.0227
# Epoch 258/300
# 27/27 [==============================] - 1s 31ms/step - loss: 0.0032 - mean_absolute_error: 0.0428 - val_loss: 0.0014 - val_mean_absolute_error: 0.0317
# Epoch 259/300
# 27/27 [==============================] - 1s 25ms/step - loss: 0.0036 - mean_absolute_error: 0.0458 - val_loss: 0.0020 - val_mean_absolute_error: 0.0382
# Epoch 260/300
# 27/27 [==============================] - 1s 28ms/step - loss: 0.0032 - mean_absolute_error: 0.0426 - val_loss: 7.8307e-04 - val_mean_absolute_error: 0.0204
# Epoch 261/300
# 27/27 [==============================] - 1s 31ms/step - loss: 0.0029 - mean_absolute_error: 0.0399 - val_loss: 7.6840e-04 - val_mean_absolute_error: 0.0204
# Epoch 262/300
# 27/27 [==============================] - 1s 28ms/step - loss: 0.0032 - mean_absolute_error: 0.0429 - val_loss: 7.8530e-04 - val_mean_absolute_error: 0.0204
# Epoch 263/300
# 27/27 [==============================] - 1s 28ms/step - loss: 0.0033 - mean_absolute_error: 0.0433 - val_loss: 0.0017 - val_mean_absolute_error: 0.0353
# Epoch 264/300
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0034 - mean_absolute_error: 0.0439 - val_loss: 7.8504e-04 - val_mean_absolute_error: 0.0206
# Epoch 265/300
# 27/27 [==============================] - 1s 28ms/step - loss: 0.0038 - mean_absolute_error: 0.0478 - val_loss: 0.0038 - val_mean_absolute_error: 0.0561
# Epoch 266/300
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0033 - mean_absolute_error: 0.0438 - val_loss: 0.0026 - val_mean_absolute_error: 0.0453
# Epoch 267/300
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0035 - mean_absolute_error: 0.0448 - val_loss: 8.0179e-04 - val_mean_absolute_error: 0.0207
# Epoch 268/300
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0037 - mean_absolute_error: 0.0472 - val_loss: 0.0016 - val_mean_absolute_error: 0.0338
# Epoch 269/300
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0031 - mean_absolute_error: 0.0417 - val_loss: 0.0048 - val_mean_absolute_error: 0.0639
# Epoch 270/300
# 27/27 [==============================] - 1s 25ms/step - loss: 0.0072 - mean_absolute_error: 0.0691 - val_loss: 0.0036 - val_mean_absolute_error: 0.0544
# Epoch 271/300
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0034 - mean_absolute_error: 0.0445 - val_loss: 0.0013 - val_mean_absolute_error: 0.0284
# Epoch 272/300
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0029 - mean_absolute_error: 0.0403 - val_loss: 7.8630e-04 - val_mean_absolute_error: 0.0205
# Epoch 273/300
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0028 - mean_absolute_error: 0.0398 - val_loss: 8.6012e-04 - val_mean_absolute_error: 0.0217
# Epoch 274/300
# 27/27 [==============================] - 1s 51ms/step - loss: 0.0031 - mean_absolute_error: 0.0423 - val_loss: 0.0056 - val_mean_absolute_error: 0.0700
# Epoch 275/300
# 27/27 [==============================] - 1s 24ms/step - loss: 0.0033 - mean_absolute_error: 0.0430 - val_loss: 0.0022 - val_mean_absolute_error: 0.0414
# Epoch 276/300
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0045 - mean_absolute_error: 0.0524 - val_loss: 7.7244e-04 - val_mean_absolute_error: 0.0202
# Epoch 277/300
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0029 - mean_absolute_error: 0.0404 - val_loss: 0.0020 - val_mean_absolute_error: 0.0388
# Epoch 278/300
# 27/27 [==============================] - 1s 31ms/step - loss: 0.0051 - mean_absolute_error: 0.0580 - val_loss: 0.0031 - val_mean_absolute_error: 0.0494
# Epoch 279/300
# 27/27 [==============================] - 1s 37ms/step - loss: 0.0045 - mean_absolute_error: 0.0518 - val_loss: 7.7341e-04 - val_mean_absolute_error: 0.0205
# Epoch 280/300
# 27/27 [==============================] - 1s 47ms/step - loss: 0.0027 - mean_absolute_error: 0.0380 - val_loss: 0.0014 - val_mean_absolute_error: 0.0318
# Epoch 281/300
# 27/27 [==============================] - 1s 32ms/step - loss: 0.0027 - mean_absolute_error: 0.0387 - val_loss: 0.0021 - val_mean_absolute_error: 0.0392
# Epoch 282/300
# 27/27 [==============================] - 1s 28ms/step - loss: 0.0039 - mean_absolute_error: 0.0486 - val_loss: 0.0020 - val_mean_absolute_error: 0.0374
# Epoch 283/300
# 27/27 [==============================] - 1s 29ms/step - loss: 0.0040 - mean_absolute_error: 0.0499 - val_loss: 0.0042 - val_mean_absolute_error: 0.0597
# Epoch 284/300
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0040 - mean_absolute_error: 0.0478 - val_loss: 0.0043 - val_mean_absolute_error: 0.0603
# Epoch 285/300
# 27/27 [==============================] - 1s 37ms/step - loss: 0.0047 - mean_absolute_error: 0.0534 - val_loss: 0.0018 - val_mean_absolute_error: 0.0367
# Epoch 286/300
# 27/27 [==============================] - 1s 28ms/step - loss: 0.0035 - mean_absolute_error: 0.0459 - val_loss: 7.9401e-04 - val_mean_absolute_error: 0.0206
# Epoch 287/300
# 27/27 [==============================] - 1s 47ms/step - loss: 0.0045 - mean_absolute_error: 0.0529 - val_loss: 0.0010 - val_mean_absolute_error: 0.0244
# Epoch 288/300
# 27/27 [==============================] - 1s 40ms/step - loss: 0.0031 - mean_absolute_error: 0.0414 - val_loss: 7.7146e-04 - val_mean_absolute_error: 0.0204
# Epoch 289/300
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0030 - mean_absolute_error: 0.0409 - val_loss: 0.0021 - val_mean_absolute_error: 0.0393
# Epoch 290/300
# 27/27 [==============================] - 1s 31ms/step - loss: 0.0044 - mean_absolute_error: 0.0511 - val_loss: 0.0027 - val_mean_absolute_error: 0.0465
# Epoch 291/300
# 27/27 [==============================] - 1s 31ms/step - loss: 0.0032 - mean_absolute_error: 0.0428 - val_loss: 8.2325e-04 - val_mean_absolute_error: 0.0219
# Epoch 292/300
# 27/27 [==============================] - 1s 25ms/step - loss: 0.0028 - mean_absolute_error: 0.0389 - val_loss: 0.0020 - val_mean_absolute_error: 0.0381
# Epoch 293/300
# 27/27 [==============================] - 1s 26ms/step - loss: 0.0032 - mean_absolute_error: 0.0426 - val_loss: 0.0016 - val_mean_absolute_error: 0.0340
# Epoch 294/300
# 27/27 [==============================] - 1s 24ms/step - loss: 0.0036 - mean_absolute_error: 0.0449 - val_loss: 0.0013 - val_mean_absolute_error: 0.0307
# Epoch 295/300
# 27/27 [==============================] - 1s 28ms/step - loss: 0.0041 - mean_absolute_error: 0.0498 - val_loss: 7.8997e-04 - val_mean_absolute_error: 0.0206
# Epoch 296/300
# 27/27 [==============================] - 1s 24ms/step - loss: 0.0030 - mean_absolute_error: 0.0424 - val_loss: 0.0045 - val_mean_absolute_error: 0.0619
# Epoch 297/300
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0038 - mean_absolute_error: 0.0481 - val_loss: 0.0075 - val_mean_absolute_error: 0.0820
# Epoch 298/300
# 27/27 [==============================] - 1s 24ms/step - loss: 0.0060 - mean_absolute_error: 0.0627 - val_loss: 0.0013 - val_mean_absolute_error: 0.0307
# Epoch 299/300
# 27/27 [==============================] - 1s 25ms/step - loss: 0.0047 - mean_absolute_error: 0.0533 - val_loss: 0.0011 - val_mean_absolute_error: 0.0278
# Epoch 300/300
# 27/27 [==============================] - 1s 24ms/step - loss: 0.0028 - mean_absolute_error: 0.0392 - val_loss: 9.9594e-04 - val_mean_absolute_error: 0.0241

# %%
#Third model observations
train_predictions3 = model3.predict(X_train2).flatten()

plt.plot(dates_train2, np.exp(train_predictions3))
plt.plot(dates_train2, np.exp(y_train2))
plt.xticks(rotation=90)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 27/27 [==============================] - 1s 8ms/step

# %%
score = model3.evaluate(X_val2, y_val2, verbose = 0) 

print('Val loss:', score[0]) 
print('Val MAE:', score[1])
# Out:
# Val loss: 0.0009959401795640588
# Val MAE: 0.024062450975179672

# %%
#Second model observations 
val_predictions3 = model3.predict(X_val2).flatten()

plt.plot(dates_val2, np.exp(val_predictions3))
plt.plot(dates_val2, np.exp(y_val2))
plt.xticks(rotation=90)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 5/5 [==============================] - 0s 21ms/step

# %%
# Third Model MAE score
score = model3.evaluate(X_test2, y_test2, verbose = 0) 

print('Test loss:', score[0]) 
print('Test MAE:', score[1])
# Out:
# Test loss: 0.000530155492015183
# Test MAE: 0.01772361621260643

# %%
test_predictions3 = model3.predict(X_test2).flatten()

plt.plot(dates_test2[-30:], np.exp(test_predictions3[-30:]))
plt.plot(dates_test2[-30:],np.exp(y_test2[-30:]))
plt.xticks(rotation=90)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 4/4 [==============================] - 0s 11ms/step

# %%
# R2 score for second model

print('R2 Score: ', r2_score(y_test2, test_predictions3))
# Out:
# R2 Score:  0.8654155311400644

# %% [markdown]
# ## Future Prediction
# - Attempting to look ahead x days in an attempt to predict upcoming trends

# %%
# Initialize an array to store predictions
predictions = []
predicted_dates = []
prediction_range = 7

#create list of numbers to add to date based on date range
date_range = list(range(1, prediction_range +1))

# Use the last n_steps data points from the training set to make predictions
current_batch = X_test2[-1]
current_reshape = current_batch.reshape((1, lookback, 1))
initial_date = dates_test2[-1]

# Generate predictions for 7 days
for i in range(prediction_range): # Generate predictions for 7 days
    # Predict the next data point
    current_pred = model3.predict(current_reshape)[0,0]
    
    # Append the prediction to the list of predictions
    predictions.append(current_pred)
        

    # Update initial input for the next step
    updated_batch = np.insert(current_batch, -1, current_pred)
    
    #resize batch 
    current_batch = updated_batch[1:]
    
    #reshape batch
    current_reshape = current_batch.reshape((1, lookback, 1))

    
for day in date_range:
    new_date = initial_date + dt.timedelta(days=day)
    predicted_dates.append(new_date
                          )
# 'predictions' contains 7-day forecast
print(predictions)

for date in predicted_dates:
    print(date)
# Out:
# 1/1 [==============================] - 1s 791ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# [7.3796515, 7.3766627, 7.376942, 7.3771887, 7.377239, 7.377294, 7.3773575]
# 2023-09-19
# 2023-09-20
# 2023-09-21
# 2023-09-22
# 2023-09-23
# 2023-09-24
# 2023-09-25

# %%
#Plot last 60 days of testing plus future prediction
plt.plot(dates_test2[-60:], np.exp(test_predictions3[-60:]))
plt.plot(dates_test2[-60:],np.exp(y_test2[-60:]))
plt.plot(predicted_dates, np.exp(predictions))
plt.xticks(rotation=90)
plt.legend(['Past Predictions', 'Past Observations','Future Predictions'])

# %%
# Export model to HDF5 file
model.save("H5_Files/eth_30_day_1.h5")

# %%
# Export model to HDF5 file
model2.save("H5_Files/eth_30_day_2.h5")

# %%
# Export model to HDF5 file
model3.save("H5_Files/eth_30_day_3.h5")

# %%
# build output into a df for graphing in js

df = pd.DataFrame({"Date": dates_test2[-90:], "observed":np.exp(y_test2[-90:]),\
                "model_1_predicted":np.exp(test_predictions[-90:]),\
                "model_2_predicted":np.exp(test_predictions2[-90:]),\
                "model_3_predicted":np.exp(test_predictions3[-90:])})
df.set_index('Date', inplace=True)

# df2 = pd.DataFrame({"Date": predicted_dates, "future_prediction":np.exp(predictions)})
# df2.set_index('Date', inplace=True)                   
                    
# past_future_df = pd.merge(df,df2, how='outer', left_index=True, right_index=True)


df
# Out:
#             observed  model_1_predicted  model_2_predicted  model_3_predicted
# Date
# 2023-06-20    1792.4        1826.348877        1766.014282        1711.332153
# 2023-06-21    1889.8        1873.546021        1787.601074        1763.880859
# 2023-06-22    1872.6        1968.188477        1831.739014        1858.845581
# 2023-06-23    1893.7        1986.855225        1865.213501        1856.149292
# 2023-06-24    1876.2        1997.961426        1897.038696        1868.207886
# ...              ...                ...                ...                ...
# 2023-09-14    1627.1        1684.114258        1659.357056        1586.120117
# 2023-09-15    1641.5        1708.454712        1665.126587        1604.279053
# 2023-09-16    1635.0        1726.542236        1674.691406        1619.368286
# 2023-09-17    1623.3        1724.972168        1681.333252        1615.136353
# 2023-09-18    1640.6        1712.147461        1683.387817        1603.031128
#
# [90 rows x 4 columns]

# %%
#Measuring each model's predictions against the test data
df[-60:].plot(use_index=True)
plt.xticks(rotation=90)

plt.legend(['Observed', 'Model 1 Predictions', 'Model 2 Predictions', \
            'Model 3 Predictions'])
plt.show()

# %%
#output prediction data to csv
df.to_csv('output/eth_predict_30.csv')

# %%
#output original historical data to csv
data.to_csv('output/eth_lifetime_30.csv')

# %%
#Scores for each model

print('Model 1 R2 Score: ', r2_score(y_test1, test_predictions))
print('Model 2 R2 Score: ', r2_score(y_test2, test_predictions2))
print('Model 3 R2 Score: ', r2_score(y_test2, test_predictions3))
# Out:
# Model 1 R2 Score:  0.38971479730248415
# Model 2 R2 Score:  0.5180416981833292
# Model 3 R2 Score:  0.8654155311400644
